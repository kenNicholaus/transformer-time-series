# %%
'''
If you are running locally then 
1. reboot your local machine
2. create an environment called 'colab' using anaconda prompt
if you have a gpu
conda create -n colab python tensorflow-gpu 
if not 
conda create -n colab python tensorflow
3. to install jupyter notebook
conda install jupyter notebook
4. to go to the 'colab' environment
activate colab
5. change file path to locate this notebook and then type 'jupyter notebook'

If you use colab
1. save the data file in your google drive
2. goto colab and start running the code
'''

# %%
#install prominent libraries with specific versions
#!pip install tensorflow==1.15.0
#!pip install keras==2.2.4-tf
#!pip install pandas==1.0.5
#!pip install sklearn==0.23.1
#!pip install matplotlib==3.2.2
#!pip install hyperas
#!pip install hyperopt

# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import os
import random
import pickle
import tensorflow as tf
#from tensorflow import keras
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, CuDNNLSTM, CuDNNGRU, Input, Activation, Flatten, BatchNormalization, Reshape
from tensorflow.python.keras.callbacks import ModelCheckpoint, TensorBoard, History, ReduceLROnPlateau
from tensorflow.python.keras.callbacks import Callback
from tensorflow.python.keras.models import Model, load_model, clone_model, save_model
from tensorflow.python.keras.layers.advanced_activations import LeakyReLU
from tensorflow.python.keras import regularizers
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from tensorflow.python.keras.wrappers.scikit_learn import KerasClassifier
import matplotlib.pyplot as plt
from matplotlib import style
from tensorflow.python.keras.optimizers import SGD, RMSprop, Adam, Adadelta
from tensorflow.python.keras.utils import np_utils
from sklearn.preprocessing import *
import datetime
from tqdm import tqdm
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.layers import Dense, Input, LSTM, Bidirectional, Activation, Conv1D, GRU, TimeDistributed
from tensorflow.python.keras.layers import Dropout, Embedding, GlobalMaxPooling1D, MaxPooling1D, Add, Flatten, SpatialDropout1D
from tensorflow.python.keras.layers import GlobalAveragePooling1D, BatchNormalization, concatenate
from tensorflow.python.keras.layers import Reshape, merge, Concatenate, Lambda, Average
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import initializers, regularizers, constraints
from tensorflow.python.keras.initializers import *
import hyperas
import hyperopt
from hyperas.distributions import choice, uniform
from hyperas import optim
from hyperopt import Trials, STATUS_OK, tpe, rand
from sklearn.metrics import confusion_matrix, roc_auc_score
import itertools
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
import pandas_market_calendars as mcal 
import datetime 
from datetime import timedelta  
import yfinance as yf
import glob 
gpus = tf.config.experimental.list_physical_devices('GPU')#Get GPU list
tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
# Out:
# Using TensorFlow backend.

# %%
#Get library versions
print("tensorflow.__version__ = ", tf.__version__)
# print("keras.__version__ = ", keras.__version__)
import sklearn 
print("sklearn.__version__ = ", sklearn.__version__)
print("numpy.__version__ = ", np.__version__)
print("pandas.__version__ = ", pd.__version__)
import matplotlib
print("matplotlib.__version__ = ", matplotlib.__version__)
now = datetime.datetime.now()
today = now.strftime("%Y-%m-%d")
print ("Last run date : ", today)
# Out:
# tensorflow.__version__ =  1.15.0
# sklearn.__version__ =  0.24.1
# numpy.__version__ =  1.20.2
# pandas.__version__ =  1.1.4
# matplotlib.__version__ =  3.2.1
# Last run date :  2021-06-11

# %%
'''
*****************************************************
please make sure the model_name is the same as the notebook
*****************************************************
'''
model_name = '8.0_Transformer_Day4' # For hyperas, it is the notebook name (make sure the notebook resides in google drive if using colab)
max_evals = 20# number of hyperas evaluations for finding hyperparameters. More choices will require to higher evaluations
early_stopping_count= 100 # stop training run if there is no improvement in accuracy after the choosen epoch count
training_epochs=1000 # Note: hyperas epochs are different from training epochs
training_verbose = 2 #2choice 0, 1, 2 or False
checkpointer_verbose = 2 #2choice 0, 1, 2 or False
call_reduce_verbose = 1 #1choice 0, 1, 2 or False
training_starting_lr = 0.001
training_monitor = 'val_acc' # can be val_acc or val_loss for this model ('loss', 'acc', 'mean_pred')

# %%
# change data parameters to improve accuracy
def data_params():
    """
    Function passes global data parameters to hyperas optim.minimize method.
    Please make ensure __pycache__ in your folder and and temp_model.py files are deleted 
    manually if you are making changes to these parameters
    """
    batch_size=64  # batch_size for training and evaluation
    time_steps = 8   # Number of time steps to create in the dataset
    rm_window =64  # Number of addtional rolling mean columns for choosen ticker price
    hyperas_epochs = 20  # number of epochs for each trails during hypears evaluation
    forecast_period = 4 # can be 1 to 7 in the 7day model
    
    '''
    ***********************************************************************************
    check to see if using 'RobustScaler','Normalizer', 'MinMaxScaler', 'MaxAbsScaler', 
    'PowerTransformer', 'QuantileTransformer' instead of 'StandardScaler' improves accuracy
    ***********************************************************************************
    '''
    x_scaler=StandardScaler() # change the method to improve accuracy
    
    return batch_size, time_steps, rm_window, hyperas_epochs, forecast_period, x_scaler

# %%
'''
***************************************************************************************************
Please choose 'True' or 'False' parameter for search, train and starting epoch one 
*****************************************************************************************************
'''

best_model_search = False # 'True' to search for best model, 'False' to use already saved existing best model
perform_training = True # 'True' to  train, 'False' to not to train after best_model search
starting_epoch_one = False # 'True' to train from scratch(epoch 1) , 'False' to load the last checkpoint weights of previous training run
evaluate_all_folds = False # evaluate the trained model for all the folds
predict = True
evaluate_only = True

# %%
def data_split():  
    kfold = False # 'True' to implement kfold, 'False' to use train_test_split
    train_size = 0.95  # use train_test_split between (0.7 to 0.9),make sure test is atleast of one batch_size
    shuffle = True # 'True' to shuffle
    split = 10 # number of splits in kfold
    fold_number = 10 # (the choosen fold_number of the split becomes test data, rest becomes train data)
    if not shuffle:
        random_state= None # for random seed
    else:
        random_state= 54        
    return kfold, train_size, shuffle, split, fold_number,random_state

# %%
def mean_pred(y_true, y_pred): # custom metrics
        return(K.mean(y_pred-y_true))

# %%
if os.path.exists('best_model/'+model_name+'.h5'):
    print('Best model exists but you can still search for a better model')
    best_model_input_shape = load_model('best_model/'+model_name+'.h5', custom_objects={'mean_pred': mean_pred}).input_shape
else:
    print('Best model doesnt exist, changing best_model variable to True')
    #best_model_search= True
    

if best_model_search and perform_training:
    print('you have choosen to search for best model and then train')
    
    
elif best_model_search and not perform_training:
    print('you have choosen to search for best model only')
   
    
elif not best_model_search and perform_training:
    if os.path.exists('train_model/'+model_name+'.h5'):
        print('you have choosen to train using already saved trained model')
        print('For training use best model batch_size:', best_model_input_shape[0])
        print('For training use best model time steps:', best_model_input_shape[1])
        print('For training use best model features:', best_model_input_shape[2])
        del best_model_input_shape
    else:
        print('There is no saved trained model')
        
elif not best_model_search and not perform_training:
     print('you have choosen to not to search or train. Therefore the model will not run')  

if os.path.exists('train_model/checkpoint/'+model_name+'_weights.h5'):
    print('check point exists with best weights')
    if os.path.exists('train_metrics/'+model_name+'.csv'):
        train_metrics = pd.read_csv('train_metrics/'+model_name+'.csv', index_col=0)
        print('\n','Results of last run checkpoint:')
        print(train_metrics.tail(1)) 
        del train_metrics
else:
    print("check point doesn't exist")
# Out:
# Best model exists but you can still search for a better model
# WARNING:tensorflow:From C:\Users\aitra\Anaconda3\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\aitra\Anaconda3\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\aitra\Anaconda3\lib\site-packages\tensorflow_core\python\ops\init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\aitra\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# you have choosen to train using already saved trained model
# For training use best model batch_size: 64
# For training use best model time steps: 8
# For training use best model features: 1516
# check point exists with best weights
#
#  Results of last run checkpoint:
#             acc      loss        lr     mean_pred   val_acc  val_loss  \
# epoch
# 109    0.998958  0.003257  0.000286  1.165564e-09  0.909375  0.532935
#
#        val_mean_pred
# epoch
# 109     5.969938e-10

# %%
#random seed to generate reproduceable results
_, _, _, _, _, random_state = data_split()
from numpy.random import seed
seed(random_state)
try:
    tf.compat.v1.set_random_seed(random_state)
except:
    from tensorflow import set_random_seed
    set_random_seed(random_state)
random.seed(random_state)
os.environ['PYTHONHASHSEED']=str(1)
os.environ['TF_KERAS'] = '1'

# %%
# create these folders if they do not exist
def build_path(dirName):
    try:
        os.makedirs(dirName)    
        print("Directory " , dirName ,  " created ")
    except:
        print("Directory " , dirName ,  " already exists")

# %%
# to check if GPU is getting used locally.....you need to see CPU as well as GPU in the output
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 5695849573655699308
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4294967296
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 625030943651750751
# physical_device_desc: "device: 0, name: GeForce RTX 2070 SUPER, pci bus id: 0000:06:00.0, compute capability: 7.5"
# ]

# %%
def feature_selection(forecast_period):
    
    '''
    Function reads the dataset and prepares inputs and labels
    '''
    ticker = '^GSPC'  # ticker to classify
    stocks = ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES', 'AFL', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL', 'ALLE', 'ALXN', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APD', 'APH', 'APTV', 'ARE', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO', 'BA', 'BAC', 'BAX', 'BBY', 'BDX', 'BEN', 'BF-B', 'BIIB', 'BIO', 'BK', 'BKNG', 'BKR', 'BLK', 'BLL', 'BMY', 'BR', 'BRK-B', 'BSX', 'BWA', 'BXP', 'C', 'CAG', 'CAH', 'CARR', 'CAT', 'CB', 'CBOE', 'CBRE', 'CCI', 'CCL', 'CDNS', 'CDW', 'CE', 'CERN', 'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COO', 'COP', 'COST', 'CPB', 'CPRT', 'CRL', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTLT', 'CTSH', 'CTVA', 'CTXS', 'CVS', 'CVX', 'CZR', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIA', 'DIS', 'DISCA', 'DISCK', 'DISH', 'DLR', 'DLTR', 'DOV', 'DOW', 'DPZ', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DX-Y.NYB', 'DXC', 'DXCM', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR', 'ENPH', 'EOG', 'EQIX', 'EQR', 'ES', 'ESS', 'ETN', 'ETR', 'ETSY', 'EVRG', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST', 'FB', 'FBHS', 'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FLT', 'FMC', 'FOX', 'FOXA', 'FRC', 'FRT', 'FTNT', 'FTV', 'GD', 'GE', 'GILD', 'GIS', 'GL', 'GLW', 'GM', 'GNRC', 'GOOG', 'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HBAN', 'HBI', 'HCA', 'HD', 'HES', 'HIG', 'HII', 'HLT', 'HOLX', 'HON', 'HPE', 'HPQ', 'HRL', 'HSIC', 'HST', 'HSY', 'HUM', 'HWM', 'IBM', 'ICE', 'IDXX', 'IEX', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC', 'INTU', 'IP', 'IPG', 'IPGP', 'IQV', 'IR', 'IRM', 'ISRG', 'IT', 'ITW', 'IVZ', 'J', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'JPM', 'K', 'KEY', 'KEYS', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KR', 'KSU', 'L', 'LB', 'LDOS', 'LEG', 'LEN', 'LH', 'LHX', 'LIN', 'LKQ', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUMN', 'LUV', 'LVS', 'LW', 'LYB', 'LYV', 'MA', 'MAA', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC', 'MKTX', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOS', 'MPC', 'MPWR', 'MRK', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MXIM', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NI', 'NKE', 'NLOK', 'NLSN', 'NOC', 'NOV', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NVR', 'NWL', 'NWS', 'NWSA', 'NXPI', 'O', 'ODFL', 'OGN', 'OKE', 'OMC', 'ORCL', 'ORLY', 'OTIS', 'OXY', 'PAYC', 'PAYX', 'PBCT', 'PCAR', 'PEAK', 'PEG', 'PENN', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'POOL', 'PPG', 'PPL', 'PRGO', 'PRU', 'PSA', 'PSX', 'PTC', 'PVH', 'PWR', 'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'REGN', 'RF', 'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG', 'RTX', 'SBAC', 'SBUX', 'SCHW', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB', 'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SPY', 'SRE', 'STE', 'STT', 'STX', 'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG', 'TDY', 'TEL', 'TER', 'TFC', 'TFX', 'TGT', 'TJX', 'TMO', 'TMUS', 'TPR', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TT', 'TTWO', 'TWTR', 'TXN', 'TXT', 'TYL', 'UA', 'UAA', 'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URI', 'USB', 'V', 'VFC', 'VIAC', 'VLO', 'VMC', 'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VTRS', 'VZ', 'WAB', 'WAT', 'WBA', 'WDC', 'WEC', 'WELL', 'WFC', 'WHR', 'WLTW', 'WM', 'WMB', 'WMT', 'WRB', 'WRK', 'WST', 'WU', 'WY', 'WYNN', 'XEL', 'XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLNX', 'XLP', 'XLU', 'XLV', 'XLY', 'XOM', 'XRAY', 'XRT', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION', 'ZTS', '^GSPC', '^IXIC', '^NDX', '^SOX', '^TNX', '^VIX', '^VVIX', '^VXN', '^VXO', '^VXV']
    short_interest = ['Trading Volume']
    nytimes = ['neg', 'neu', 'pos']
    economic = ['Dividend', 'Earnings', 'CPI', 'Long Interest Rate', 'Real Price', 'Real Dividend', 'Real Earnings', 'Cyclically Adjusted PE Ratio', 'ECRI USLEADING LEVEL', 'ECRI USLEADING GROWTH', 'ECRI USLAGGING LEVEL', 'ECRI USLAGGING GROWTH', 'ECRI_USCOIN LEVEL', 'ECRI_USCOIN GROWTH', 'University of Michigan Consumer Survey, Index of Consumer Sentiment', 'Bullish', 'Neutral', 'Bearish', 'Bullish 8-Week Mov Avg', 'Bull-Bear Spread', 'Bullish Average', 'Bullish Average + St. Dev', 'Bullish Average - St. Dev', 'Stock Market Confidence Indices - United States One Year Index Data - Individual', 'Stock Market Confidence Indices - United States One Year Index Data - Institutional', 'Stock Market Confidence Indices - United States Buy on Dips Confidence Index Data - Individual', 'Stock Market Confidence Indices - United States Buy on Dips Confidence Index Data - Institutional', 'Stock Market Confidence Indices - United States Crash Confidence Index Data - Individual', 'Stock Market Confidence Indices - United States Crash Confidence Index Data - Institutional', 'Stock Market Confidence Indices - United States Valuation Index Data - Individual', 'Stock Market Confidence Indices - United States Valuation Index Data - Institutional', 'Zillow Home Value Index (Metro): Zillow Rental Index - All Homes - United States', 'Zillow Home Value Index (Metro): Turnover - All Homes - United States', 'Zillow Home Value Index (Metro): Price To Rent Ratio - All Homes - United States', 'Zillow Home Value Index (Metro): Median Listing Price - All Homes - United States', 'Zillow Home Value Index (Metro):  Home Sold As Foreclosure - Ratio - All Homes - United States', 'Historical Housing Market Data - Real Home Price Index', 'Cost Index', 'U.S. Population (Millions)', 'Long Rate', 'Historical Housing Market Data - Nominal Home Price Index', 'Historical Housing Market Data - Consumer Price Index (Quarterly)', '30-Year Conventional Mortgage Rate', 'House Price Index - US National', '15-Year Fix Rate', '15-Year Fix Rate Fees & Points', '5-Year Adjustable Rate', '5-Year Adjustable Rate Fees & Points', '1-Year Adjustable Rate', '1-Year Adjustable Rate Fees & Points', '30-Year Fixed Rate Mortgage Average in the United States', 'Federal Funds Rate', '90 day T Bill Rate', 'One Year Maturity Treasury Yield', 'Ten Year Maturity Treasury Yield', 'Freddie Mac Commitment Fixed Rate Mortgages', 'Freddie Mac Commitment ARMs', 'Prime Rate', 'Total Housing Starts', 'Single Family Housing Starts', 'Multi-Family Housing Starts', 'New Single-Family Sales', 'Existing Single-Family Home Sales', '1-Year CD: National Rate of Banks', '5-Year CD: National Rate of Banks', 'Interest Checking Accounts: National Rate of Banks', 'Money Market Accounts: National Rate of Banks', '1-Month AA Financial Commercial Paper Rate', '3-Month AA Financial Commercial Paper Rate', '1-Month AA Nonfinancial Commercial Paper Rate', '3-Month AA Nonfinancial Commercial Paper Rate', 'Effective Federal Funds Rate', '10-Year Treasury Inflation-Indexed Security, Constant Maturity', '20-Year Treasury Inflation-Indexed Security, Constant Maturity', '30-Year Treasury Inflation-Indexed Security, Constant Maturity', '5-Year Treasury Inflation-Indexed Security, Constant Maturity', '7-Year Treasury Inflation-Indexed Security, Constant Maturity', '10-Year Treasury Constant Maturity Rate', '2-Year Treasury Constant Maturity Rate', '20-Year Treasury Constant Maturity Rate', '3-Year Treasury Constant Maturity Rate', '30-Year Treasury Constant Maturity Rate', '5-Year Treasury Constant Maturity Rate', '7-Year Treasury Constant Maturity Rate', 'Bank Prime Loan Rate', '1-Year Treasury Bill: Secondary Market Rate', '3-Month Treasury Bill: Secondary Market Rate', '4-Week Treasury Bill: Secondary Market Rate', '6-Month Treasury Bill: Secondary Market Rate', 'Overnight London Interbank Offered Rate (LIBOR), based on U.S. Dollar', 'Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan', 'Commercial Bank Interest Rate on Credit Card Plans, All Accounts', 'RR3_TBILL_PGDP_2', 'RR3_TBILL_PGDP_3', 'RR3_TBILL_PGDP_4', 'RR3_TBILL_PGDP_5', 'RR2_TBILL_CCPI_2', 'RR2_TBILL_CCPI_3', 'RR2_TBILL_CCPI_4', 'RR2_TBILL_CCPI_5', 'Gross domestic product', 'Personal consumption expenditures', ':Goods', '::Durable goods', '::Nondurable goods', ':Services', 'Gross private domestic investment', 'Net exports of goods and services', 'Government consumption expenditures and gross investment', '::Gross domestic income (GDI)', '::Gross national product', '::Gross national income', '::Disposable personal income', 'Personal income', ':Compensation of employees', '::Wages and salaries', ':Population (midperiod; thousands)', '::Disposable personal income; current dollars', 'Services', ':Household consumption expenditures (for services)', '::Housing and utilities', '::Health care', '::Transportation services', '::Recreation services', '::Food services and accommodations', '::Financial services and insurance', '::Other services', 'Corporate profits with inventory valuation and capital consumption adjustments', 'Consumer Price Index - USA', 'United States Gross National Savings, % of GDP', 'United States GDP at Constant Prices, % change', 'Nominal Potential Gross Domestic Product', 'Industrial Production: Durable Goods: Other durable goods', 'FRED: Projection of General government net lending/borrowing for United States', 'FRED: Real Potential Gross Domestic Product', 'FRED: Real Gross Domestic Product', 'FRED: Gross Domestic Product', 'FRBP: GDPplus GDP Growth', 'Inflation YOY - USA', 'Consumer Price Index for All Urban Consumers: All Items', 'PRCCPI1', 'PRCCPI2', 'PRCCPI3', 'PRCCPI4', 'PRCCPI5', 'PRCCPI6', 'PRCCPI7', 'PRCCPI8', 'PRCCPI9', 'PRCCPI10', 'PRCCPI11', 'PRCCPI12', 'PRCCPI13', 'PRCCPI14', 'PRCCPI15', 'PRCCPI16', 'PRCCPI17', 'PRCCPI18', 'PRCCPI19', 'PRCCPI20', 'Mean CPI1', 'Mean CPI2', 'Mean CPI3', 'Mean CPI4', 'Mean CPI5', 'Mean CPI6', 'Mean CPIA', 'Mean CPIB', 'Mean CPIC', 'Median CPI1', 'Median CPI2', 'Median CPI3', 'Median CPI4', 'Median CPI5', 'Median CPI6', 'Median CPIA', 'Median CPIB', 'Median CPIC', 'CORECPI1', 'CORECPI2', 'CORECPI3', 'CORECPI4', 'CORECPI5', 'CORECPI6', 'CORECPIA', 'CORECPIB', 'CORECPIC', 'Median CORECPI1', 'Median CORECPI2', 'Median CORECPI3', 'Median CORECPI4', 'Median CORECPI5', 'Median CORECPI6', 'Median CORECPIA', 'Median CORECPIB', 'Median CORECPIC', 'Employment; Openings; All industries; Rate (Percent) - National', 'Employment; Gross Job Losses; All industries; Rate (Percent) - National', 'Employment - All employees, quarterly averages, seasonally adjusted, thousands; Total nonfarm industry', 'Employment - All employees, thousands; Total private industry', 'Employment - All employees, thousands; Total nonfarm industry', 'Hires for Total nonfarm in Total US Region', 'Layoffs and discharges for Total nonfarm in Total US Region', 'Total separations for Total nonfarm in Total US Region', 'Hires percent for Total private in Total US Region', 'Job openings for Total private in Total US Region', 'Job openings percent for Total private in Total US Region', 'Total separations for Total private in Total US Region', 'Hires for Construction in Total US Region', 'Total separations for Construction in Total US Region', 'Hires for Manufacturing in Total US Region', 'Hires for Government in Total US Region', 'Total separations for Government in Total US Region', 'US Forecast Unemployment Rate, % of Total Labor Force', 'ISM Manufacturing Employment Index', 'ISM Non-Manufacturing Employment Index', 'FRED Forecast Natural Rate of Unemployment (Short-Term)', 'FRED Forecast Natural Rate of Unemployment (Long-Term)', 'ADP_Total private', 'ADP_Goods producing', 'Service providing', 'ADP_Goods Producing Industries_1-19', 'ADP_Goods Producing Industries_20-49', 'ADP_Goods Producing Industries_1-49', 'ADP_Goods Producing Industries_50-499', 'ADP_Goods Producing Industries_500+', 'ADP_Goods Producing Industries_500-999', 'ADP_Goods Producing Industries_1,000+', 'ADP_Construction', 'ADP_Natural resources & mining', 'Manufacturing', 'ADP_Prof.l/business services', 'ADP_Professional services', 'ADP_Total Non-Farm Private_1-19', 'ADP_Total Non-Farm Private_20-49', 'ADP_Total Non-Farm Private_1-49', 'ADP_Total Non-Farm Private_50-499', 'ADP_Total Non-Farm Private_500+', 'ADP_Total Non-Farm Private_500-999', '1000+', 'ADP_Private Service_1-19', 'ADP_Private Service_20-49', 'ADP_Private Service_1-49', 'ADP_Private Service_50-499', 'ADP_Private Service_500+', 'ADP_Private Service_500-999', 'ADP_Private Service_1,000+', 'Hand to Mouth-Manufacturing Buying Policy: Capital Expenditures', 'Average Days-Manufacturing Buying Policy: Capital Expenditures', 'Hand to Mouth-Manufacturing Buying Policy: MRO Supplies', 'Average Days-Manufacturing Buying Policy: MRO Supplies', 'Manufacturing Backlog of Orders Index', "Manufacturing Customers' Inventories Index", 'Manufacturing Supplier Deliveries Index', 'Manufacturing New Export Orders Index', 'Manufacturing Imports Index', 'Manufacturing Inventories Index', 'Manufacturing New Orders Index', 'Manufacturing Prices Index', 'Manufacturing Production Index', 'Non-Manufacturing Backlog of Orders Index', 'Non-Manufacturing Business Activity Index', 'Non-Manufacturing Supplier Deliveries Index', 'Non-Manufacturing New Export Orders Index', 'Non-Manufacturing Imports Index', 'Non-Manufacturing Inventories Index', 'Non-Manufacturing Inventory Sentiment Index', 'Non-Manufacturing New Orders Index', 'NMI Non-Manufacturing Index', 'Non-Manufacturing Prices Index', 'Gold Prices (Daily) - Currency USD', 'Milk, Nonfat dry, Chicago', 'Crude Oil Futures, Continuous Contract #1 (CL1) (Front Month)', 'UK Natural Gas Futures, Continuous Contract', 'Natural Gas (Henry Hub) Physical Futures, Continuous Contract #1 (NG1) (Front Month)', 'STEO price forecast, Monthly', 'US All Grades Conventional Gas Price', 'Copper Prices', 'Aluminum Prices', 'Silver Price: London Fixing', 'Seasonal Factors for the Empire State Manufacturing Survey - Future General Business Conditions - Percent Reporting Increase', 'Empire State Manufacturing Index - Forecasted Inventories - Diffusion Index (Seasonally Adjusted)', 'Seasonal Factors for the Empire State Manufacturing Survey - Current New Orders - Percent Reporting Decrease', 'Seasonal Factors for the Empire State Manufacturing Survey - Current New Orders - Percent Reporting Increase', 'Empire State Manufacturing Index - Forecasted Shipments - Diffusion Index (Seasonally Adjusted)', 'Empire State Manufacturing Index - Forecasted Unfilled Orders - Diffusion Index (Seasonally Adjusted)', 'Philly Fed Seasonally Adjusted Diffusion Indexes - Future New Orders', 'Philly Fed Seasonally Adjusted Diffusion Indexes - Future Shipments', 'Philly Fed Seasonally Adjusted Diffusion Indexes - Future Unfilled Orders', 'Future New Orders;Percent Reporting Increases for FRB - Philadelphia District']
    pattern = ['weekday_1', 'weekday_2', 'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 
    # add the list name with the '+' sign, stocks are prerequisite for calculating rolling mean
    
    selected_features = stocks+short_interest+nytimes+economic+pattern+correlations+technicals
    

    data_file = '../../models/process/sp500/data/'+ticker+'/'+ticker+'_7_days_0_return.csv'

    df=pd.read_csv(data_file, index_col = 0, parse_dates = True)['01-01-1993':] 
    df=df[:-forecast_period] # if target return & Y target have NaN for forecast periods    
    y = df[['^GSPC_{}d_target'.format(forecast_period)]]
   
    
    df = df[selected_features]
    remove_columns=([i for i in df.columns if df[i].isnull().any()]) # find Nan columns
    print('removed columns: ', remove_columns)
    df.drop(remove_columns, axis=1, inplace=True) # drop columns with NaN
    
    try: #to prevent error from not choosing the 'stocks' list for the dataframe(no ticker column)
        for a in range(2,rm_window+1):
            df[ticker+'rm_'+str(a)] = df[ticker].rolling(window=rm_window,center=False).mean()
        print('rolling mean columns added: ', rm_window)
        df = df[rm_window:] # slice to remove top rows with Nan generated due to rolling mean calc
        y = y[rm_window:] # slice to remove top rows with Nan generated due to rolling mean calc
    except:
        print('no stock ticker column selected. Therefore no rolling mean column added')
        pass
    
    

    return df, y, ticker

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps+1): 
        v = X[i:(i + time_steps)]
        Xs.append(v)
        ys.append(y[(i-1) + time_steps])
    return np.array(Xs), np.array(ys)

# %%
def percent_change(df):
    df=df.pct_change()
    df=df.replace([np.inf, -np.inf],np.nan) 
    df.fillna(0, inplace=True)
    df.isnull().any().mean()
    return df

# %%
def data():
    '''
    Function applies percent change and prepares the data for machine learning model
    '''
    batch_size, time_steps, rm_window, hyperas_epochs, forecast_period, x_scaler = data_params()
    df, y, ticker = feature_selection(forecast_period)
    kfold, train_size, shuffle, split, fold_number,random_state = data_split()
    

    # add percent change
    df = percent_change(df)

    # apply preprocessing 
    x = x_scaler.fit_transform(df)
    del df
    
        
    y = y.values
    

    # apply time steps, modified to match the last day of time steps x with last day of timesteps y instead of next day, 
     #also added latest(of the last of the series), was not present earlier
    
    x, y = create_dataset(x, y, time_steps)
    


   
    x_predict = x[-batch_size:]
  

    #implementation of fold
    if kfold:
        count = 0
        fd = KFold(n_splits=split, random_state=random_state, shuffle=shuffle)

        for train_index, test_index in fd.split(x):
            count +=1
            if count == fold_number: 
                x_train, x_test,y_train, y_test  = x[train_index], x[test_index], y[train_index], y[test_index]
                del x, y, train_index, test_index
                print('Prepated data for a kfold split of ', split, ' with the fold number ', fold_number)
    else:
        x_train, x_test, y_train, y_test=train_test_split(x,y, train_size=train_size, random_state=random_state, shuffle=shuffle)
        print('Prepared data with a train_test_split of ', train_size) 


    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    
    
    y_train = np_utils.to_categorical(y_train, 2, dtype='float32')
    y_test = np_utils.to_categorical(y_test, 2, dtype='float32')
   

    # adjustment for batch_size
    train_start = x_train.shape[0]%batch_size
    test_start = x_test.shape[0]%batch_size
    x_train = x_train[train_start:]
    y_train = y_train[train_start:] 

    x_test = x_test[test_start:]
    y_test = y_test[test_start:]


    return x_train, x_test, y_train, y_test, batch_size,hyperas_epochs,x_predict, forecast_period, ticker

# %%
def create_transformer_model(x_train, y_train, x_test, y_test, batch_size):
    

    dropout_choice = {{uniform(0, 1)}}
    final_dropout_choice = {{uniform(0, 0.3)}}
    activation_choice = {{choice(['relu', 'tanh', 'selu', 'elu'])}}
    optimizer_choice = {{choice(['sgd','rmsprop','adam', 'adadelta'])}}
    head = {{choice([2, 4, 8])}}
    query_d = {{choice([64])}} # make sure query_d is divisible by head without a remainder
    n_encoders = {{choice([1, 2, 3, 4, 5, 6])}}
    inputA = Input(batch_shape=(batch_size, x_train.shape[1], x_train.shape[2]), name='input_1')
    mask = None
    
    
    def point_wise_feed_forward_network(max_token):
          return tf.keras.Sequential([
              tf.keras.layers.Dense(query_d, activation='relu'),  # (batch_size, seq_len, dimension_of_neural_network_unit_in_feed_forward_network)
              tf.keras.layers.Dense(max_token)  # (batch_size, seq_len, d_model)
          ])
    
    def scaled_dot_product_attention(q, k, v, mask):
        matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
        dk = tf.cast(tf.shape(k)[-1], tf.float32)
        scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)
        if mask is not None:
            scaled_attention_logits += (mask * -1e20)          
        attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)
        output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)
        return output, attention_weights
    
    def split_heads(x, batch_size):
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def reshape1(x):
        s = tf.shape(x)   
        x = tf.reshape(x, [s[0], s[1], head, query_d])
        x = tf.transpose(x, [2, 0, 1, 3])  
        x = tf.reshape(x, [-1, s[1], query_d])  # [n_head * batch_size, len_q, d_k]
        return x
    
    def reshape2(x):
        s = tf.shape(x)   # [n_head * batch_size, len_v, d_v]
        x = tf.reshape(x, [head, -1, s[1], s[2]]) 
        x = tf.transpose(x, [1, 2, 0, 3])
        x = tf.reshape(x, [-1, s[1], head*query_d])  # [batch_size, len_v, n_head * d_v]
        return x    

       
    
    def mah_encoder_model(x, mask, query_d, head, ninitial, rate, layer):
        if ninitial:
            previous = x
        else:
            previous = tf.keras.layers.Dense(query_d)(x)         
        q = tf.keras.layers.Dense(query_d*head)(x)  
        k = tf.keras.layers.Dense(query_d*head)(x)
        v = tf.keras.layers.Dense(query_d*head)(x)    
        q = reshape1(q)
        k = reshape1(k)
        v = reshape1(v)    
        scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)    
        ma_output = reshape2(scaled_attention)    
        ma_output = tf.keras.layers.Dense(query_d)(ma_output)
        ln_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(previous+ma_output)
        ln_output = tf.keras.layers.Dropout(rate)(ln_output) 
        ff_output = point_wise_feed_forward_network(query_d)(ln_output) 
        ln_output = tf.keras.layers.LayerNormalization(epsilon=1e-6)(ff_output+ln_output)
        residual = tf.keras.layers.Dropout(rate)(ln_output)
        return residual
    
    
    
    
    def get_encoder(x, mask, n_encoders, query_d, head, rate):
        ninitial = False     
        for layer in range(n_encoders):
            if(layer == 0):
                residual = mah_encoder_model(x, mask, query_d, head, ninitial, rate, layer)
                ninitial = True        
            else: 
                residual = mah_encoder_model(residual, mask, query_d, head, ninitial, rate, layer)                        
        en_output = residual
        return en_output
    
    
    x1 = get_encoder(inputA, mask, n_encoders=n_encoders, query_d=query_d,head=head, rate=dropout_choice)
    x2 = Flatten(name='x2')(x1)
    day7 = Dense(2, name='day7', activation="softmax")(x2)
    
    model = Model(inputs=[inputA], outputs=[day7])
    
    
    def mean_pred(y_true, y_pred):
        return(K.mean(y_pred-y_true))
    
    ##model.summary()
    
    model.compile(loss=['categorical_crossentropy'], 
                  metrics=['accuracy',mean_pred],
                  optimizer = optimizer_choice)
    
    from keras import callbacks
    reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_mean_pred', factor=0.95, mode='min', patience=3,
                                            min_lr=0.01, min_delta=0.0001, cooldown=0, verbose=1)
   
    result = model.fit([x_train], [y_train],  batch_size=batch_size, 
                       validation_data=([x_test], [y_test]), 
                         epochs=hyperas_epochs, verbose=False,  callbacks=[reduce_lr])
    
    #print(result.history.keys())   
    val_acc = (np.max(result.history['val_acc']))     
    return {'loss': -val_acc, 'status': STATUS_OK, 'model': model}

# %%
class PrintingLR(Callback):
    def on_epoch_end(self, epoch, logs=None):
        #if epoch % 10 == 1:
        lr = self.model.optimizer.lr
        print('Learning_rate :', K.eval(lr))

# %%
def get_callback(early_stopping_count):
    '''
    Function returns callbacks for training the model
    '''
    build_path('train_model')
    build_path("logs")
    build_path('train_metrics')
    
    
    checkpointer = ModelCheckpoint('train_model/'+model_name+'.h5',save_best_only=True, monitor=training_monitor, 
                                   mode='auto', verbose=checkpointer_verbose)
    
    save_weights = ModelCheckpoint('train_model/checkpoint/'+model_name+'_weights.h5', save_weights_only=True, save_best_only=True,
                                monitor=training_monitor,mode='auto', verbose=False)
    
    call_reduce = ReduceLROnPlateau(monitor=training_monitor, factor=0.98, mode='auto', patience=5, min_lr=0.00000001, 
                                             min_delta=0.00001, cooldown=0, verbose=call_reduce_verbose)
    callback_es = tf.keras.callbacks.EarlyStopping(monitor=training_monitor,mode='auto', patience=early_stopping_count)
    
    print_lr = PrintingLR()
    def scheduler(epoch, lr):
        if epoch < 10:
            return lr
        else:
            return lr * tf.math.exp(-0.1)
    tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
    callback_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)    
    #callback_pl = tf.keras.callbacks.ProgbarLogger(count_mode="samples")
    callback_csv = tf.keras.callbacks.CSVLogger(filename = 'train_metrics/'+model_name+".csv")
    
    return checkpointer,save_weights, call_reduce, callback_lr, callback_es, print_lr, callback_csv

# %%
def draw_history(history):
    '''
    Function charts the training history for loss, accuracy and learning rate
    '''
    #print(history.history.keys())
    keys = ['loss', 'acc', 'mean_pred']
    
    
    
    for i in keys:
        plt.plot(history.history[i])
        plt.plot(history.history['val_'+i])
        plt.title('model '+i)
        plt.ylabel(i.upper())
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='best')
        plt.show()
    
    
    # summarize history for learning rate
    plt.plot(history.history['lr'])
    plt.title('learning rate progress')
    plt.ylabel('learning rate')
    plt.xlabel('epoch')
    plt.legend(['learning rate'], loc='best')
    plt.show()

# %%
class_names = ['BUY', 'SELL']


def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion Matrix',cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print(cm)
    plt.figure()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=10)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    #plt.figure(figsize = (10,10))
    plt.savefig('train_model/'+model_name+'.png', facecolor='yellowgreen',bbox_inches='tight', dpi=100)
    plt.show()

# %%
def evaluate(model, x_test, x_predict, y_test, batch_size, forecast_period):
    day_prediction_test = (np.argmax(model.predict([x_test], batch_size=batch_size), axis=1))
    
    day_actual_test = np.argmax(y_test, axis=1)  
    cnf_matrix = confusion_matrix(day_actual_test, day_prediction_test)
    plot_confusion_matrix(cnf_matrix, classes=class_names, title='Confusion Matrix on test data')
    ROC_AUC_SCORE=(roc_auc_score(day_actual_test, day_prediction_test))
    print('DAY7 ROC_AUC_SCORE: ',ROC_AUC_SCORE)

# %%
def get_params(model):
    trainable_params = int(np.sum([K.count_params(p) for p in set(model.trainable_weights)]))
    non_trainable_params = int(np.sum([K.count_params(p) for p in set(model.non_trainable_weights)]))
    return trainable_params, non_trainable_params

# %%
def get_best_model_optimizer():
    f = open('best_model/'+model_name+'_best_run.pickle', 'rb')# read best_run parameters from a pickle file
    best_run = pickle.load(f)
    f.close()
    choosen_optimizer = best_run['optimizer_choice']
    
    if choosen_optimizer == 'rmsprop':
        refined_optimizer = RMSprop(training_starting_lr)
    elif choosen_optimizer == 'adam':
        refined_optimizer = Adam(training_starting_lr)
    elif choosen_optimizer == 'sgd':
        refined_optimizer = SGD(training_starting_lr)
    elif choosen_optimizer == 'adadelta':
        refined_optimizer = Adadelta(training_starting_lr)
        
    return refined_optimizer

# %%
def training():
    def mean_pred(y_true, y_pred):
        return(K.mean(y_pred-y_true))
    
    if not starting_epoch_one:
        model = load_model('train_model/'+model_name+'.h5', custom_objects={'mean_pred': mean_pred})
        print('Loaded best trained model from previous runs with the best weights')
        optimizer = model.optimizer
    else:
        model = load_model('best_model/'+model_name+'.h5', custom_objects={'mean_pred': mean_pred})
        print('Loaded best untrained model to begin training from the beginning')
        optimizer = get_best_model_optimizer()
        
          
    print('*'*30+'params'+'*'*30)
    trainable_params, non_trainable_params = get_params(model)
    print('Trainable_params :', trainable_params)
    print('Non_trainable_params :', non_trainable_params)
    print('*'*30+'params'+'*'*30)
    #model.summary()
    
    

    model.compile(loss=['categorical_crossentropy'],
                  optimizer = optimizer,
                  metrics=['accuracy',mean_pred])

    checkpointer,save_weights, call_reduce, callback_lr, callback_es, print_lr, callback_csv = get_callback(early_stopping_count)
    tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

    callbacks_list = [checkpointer,save_weights, call_reduce, callback_es, print_lr, callback_csv, tensorboard]

    history = model.fit([x_train], [y_train], batch_size=batch_size, epochs=training_epochs,
                        verbose=training_verbose, validation_data=([x_test], [y_test]), callbacks=callbacks_list)
    
    loss, accuracy, mean_pred = model.evaluate([x_test], [y_test], batch_size=batch_size)
    print('accuracy: ', accuracy,'mean_pred: ', mean_pred )
    draw_history(history)
    def mean_pred(y_true, y_pred):
        return(K.mean(y_pred-y_true))
    model = load_model('train_model/'+model_name+'.h5', custom_objects={'mean_pred': mean_pred})
    evaluate(model, x_test, x_predict, y_test,batch_size, forecast_period)

# %%
if best_model_search:
    if __name__ == '__main__':

        best_run, best_model = optim.minimize(model=create_transformer_model, 
                                              data=data,functions = [data_params, data_split, feature_selection, percent_change, create_dataset],
                                              algo=tpe.suggest,max_evals=max_evals,trials=Trials(), notebook_name=model_name,rseed=1, eval_space=True, verbose=False)

        batch_size, time_steps, rm_window, hyperas_epochs, forecast_period, x_scaler = data_params()
        x_train, x_test, y_train, y_test, batch_size,hyperas_epochs,x_predict, forecast_period, ticker= data()
        print(x_train.shape, y_train.shape)

        print("Evaluation of best performing model:")
        build_path('best_model')
        best_model.save('best_model/'+model_name+'.h5')
        f = open('best_model/'+model_name+'_best_run.pickle', 'wb')# save best_run parameters in a pickle file
        pickle.dump(best_run, f)
        f.close()
        #print(best_model.get_config())
        #print(best_model.metrics_names)
        loss,accuracy,mean_pred = best_model.evaluate([x_test], [y_test], batch_size=batch_size)
        print('accuracy: ', accuracy,'mean_pred: ',mean_pred)
        print("Best performing model chosen hyper-parameters:")
        print(best_run)
    
if  perform_training:
    kfold, train_size, shuffle, split, fold_number,random_state = data_split()
    batch_size, time_steps, rm_window, hyperas_epochs, forecast_period, x_scaler = data_params()           
    x_train, x_test, y_train, y_test, batch_size,hyperas_epochs,x_predict, forecast_period, ticker= data()
    training()
    del x_train, x_test,y_train, y_test, x_predict
# Out:
# removed columns:  []
# rolling mean columns added:  64
# Prepared data with a train_test_split of  0.95
# Loaded best trained model from previous runs with the best weights
# ******************************params******************************
# Trainable_params : 739266
# Non_trainable_params : 0
# ******************************params******************************
# Directory  train_model  already exists
# Directory  logs  already exists
# Directory  train_metrics  already exists
# Train on 6720 samples, validate on 320 samples
# Epoch 1/1000
#
# Epoch 00001: val_acc improved from -inf to 0.93125, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00041948963
# 6720/6720 - 4s - loss: 0.3576 - acc: 0.8815 - mean_pred: 1.4174e-10 - val_loss: 0.1886 - val_acc: 0.9312 - val_mean_pred: 5.1735e-10
# Epoch 2/1000
#
# Epoch 00002: val_acc improved from 0.93125 to 0.93437, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.1517 - acc: 0.9394 - mean_pred: -1.4232e-10 - val_loss: 0.1719 - val_acc: 0.9344 - val_mean_pred: -5.4749e-10
# Epoch 3/1000
#
# Epoch 00003: val_acc improved from 0.93437 to 0.93750, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0993 - acc: 0.9621 - mean_pred: -2.8812e-10 - val_loss: 0.1636 - val_acc: 0.9375 - val_mean_pred: -2.4283e-09
# Epoch 4/1000
#
# Epoch 00004: val_acc improved from 0.93750 to 0.94063, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0609 - acc: 0.9753 - mean_pred: -1.0918e-10 - val_loss: 0.1732 - val_acc: 0.9406 - val_mean_pred: 2.7712e-10
# Epoch 5/1000
#
# Epoch 00005: val_acc did not improve from 0.94063
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0478 - acc: 0.9817 - mean_pred: -4.6130e-10 - val_loss: 0.2122 - val_acc: 0.9312 - val_mean_pred: -2.4450e-10
# Epoch 6/1000
#
# Epoch 00006: val_acc did not improve from 0.94063
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0409 - acc: 0.9847 - mean_pred: -2.9777e-10 - val_loss: 0.1857 - val_acc: 0.9375 - val_mean_pred: -1.4631e-09
# Epoch 7/1000
#
# Epoch 00007: val_acc improved from 0.94063 to 0.94375, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0346 - acc: 0.9888 - mean_pred: 3.2983e-10 - val_loss: 0.2064 - val_acc: 0.9438 - val_mean_pred: -4.4822e-10
# Epoch 8/1000
#
# Epoch 00008: val_acc did not improve from 0.94375
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0266 - acc: 0.9887 - mean_pred: -3.0010e-10 - val_loss: 0.2326 - val_acc: 0.9406 - val_mean_pred: 1.4626e-09
# Epoch 9/1000
#
# Epoch 00009: val_acc improved from 0.94375 to 0.94687, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0222 - acc: 0.9935 - mean_pred: -1.3302e-10 - val_loss: 0.1753 - val_acc: 0.9469 - val_mean_pred: 4.6822e-10
# Epoch 10/1000
#
# Epoch 00010: val_acc did not improve from 0.94687
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0225 - acc: 0.9933 - mean_pred: -1.2143e-10 - val_loss: 0.2191 - val_acc: 0.9438 - val_mean_pred: -6.3575e-10
# Epoch 11/1000
#
# Epoch 00011: val_acc did not improve from 0.94687
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0216 - acc: 0.9932 - mean_pred: 1.5668e-11 - val_loss: 0.2099 - val_acc: 0.9312 - val_mean_pred: 1.9614e-09
# Epoch 12/1000
#
# Epoch 00012: val_acc did not improve from 0.94687
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0138 - acc: 0.9957 - mean_pred: -8.3065e-11 - val_loss: 0.1909 - val_acc: 0.9406 - val_mean_pred: 1.0360e-09
# Epoch 13/1000
#
# Epoch 00013: val_acc did not improve from 0.94687
# Learning_rate : 0.00041948963
# 6720/6720 - 1s - loss: 0.0152 - acc: 0.9954 - mean_pred: -1.4457e-10 - val_loss: 0.2338 - val_acc: 0.9281 - val_mean_pred: -2.0422e-09
# Epoch 14/1000
#
# Epoch 00014: val_acc did not improve from 0.94687
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0004110998392570764.
# Learning_rate : 0.00041109984
# 6720/6720 - 1s - loss: 0.0156 - acc: 0.9940 - mean_pred: 1.8746e-10 - val_loss: 0.2256 - val_acc: 0.9406 - val_mean_pred: 1.6658e-09
# Epoch 15/1000
#
# Epoch 00015: val_acc did not improve from 0.94687
# Learning_rate : 0.00041109984
# 6720/6720 - 1s - loss: 0.0212 - acc: 0.9936 - mean_pred: 7.9893e-11 - val_loss: 0.2274 - val_acc: 0.9469 - val_mean_pred: 9.2414e-10
# Epoch 16/1000
#
# Epoch 00016: val_acc improved from 0.94687 to 0.95625, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00041109984
# 6720/6720 - 1s - loss: 0.0167 - acc: 0.9949 - mean_pred: 1.9086e-10 - val_loss: 0.2439 - val_acc: 0.9563 - val_mean_pred: 2.3264e-09
# Epoch 17/1000
#
# Epoch 00017: val_acc did not improve from 0.95625
# Learning_rate : 0.00041109984
# 6720/6720 - 1s - loss: 0.0119 - acc: 0.9960 - mean_pred: 5.3858e-10 - val_loss: 0.2456 - val_acc: 0.9500 - val_mean_pred: 6.9100e-10
# Epoch 18/1000
#
# Epoch 00018: val_acc did not improve from 0.95625
# Learning_rate : 0.00041109984
# 6720/6720 - 1s - loss: 0.0131 - acc: 0.9954 - mean_pred: 5.6580e-10 - val_loss: 0.2718 - val_acc: 0.9438 - val_mean_pred: 1.6626e-09
# Epoch 19/1000
#
# Epoch 00019: val_acc did not improve from 0.95625
# Learning_rate : 0.00041109984
# 6720/6720 - 1s - loss: 0.0132 - acc: 0.9949 - mean_pred: 3.3930e-10 - val_loss: 0.2305 - val_acc: 0.9406 - val_mean_pred: 4.7178e-10
# Epoch 20/1000
#
# Epoch 00020: val_acc did not improve from 0.95625
# Learning_rate : 0.00041109984
# 6720/6720 - 1s - loss: 0.0122 - acc: 0.9957 - mean_pred: 6.8374e-10 - val_loss: 0.1966 - val_acc: 0.9438 - val_mean_pred: -2.9131e-10
# Epoch 21/1000
#
# Epoch 00021: val_acc did not improve from 0.95625
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00040287784475367516.
# Learning_rate : 0.00040287783
# 6720/6720 - 1s - loss: 0.0113 - acc: 0.9963 - mean_pred: 5.3389e-10 - val_loss: 0.2490 - val_acc: 0.9344 - val_mean_pred: 8.6018e-10
# Epoch 22/1000
#
# Epoch 00022: val_acc improved from 0.95625 to 0.95938, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00040287783
# 6720/6720 - 1s - loss: 0.0120 - acc: 0.9954 - mean_pred: 5.1763e-10 - val_loss: 0.2083 - val_acc: 0.9594 - val_mean_pred: -1.6901e-09
# Epoch 23/1000
#
# Epoch 00023: val_acc did not improve from 0.95938
# Learning_rate : 0.00040287783
# 6720/6720 - 1s - loss: 0.0113 - acc: 0.9964 - mean_pred: 7.9056e-10 - val_loss: 0.2020 - val_acc: 0.9406 - val_mean_pred: 4.4859e-10
# Epoch 24/1000
#
# Epoch 00024: val_acc did not improve from 0.95938
# Learning_rate : 0.00040287783
# 6720/6720 - 1s - loss: 0.0137 - acc: 0.9951 - mean_pred: 5.8444e-10 - val_loss: 0.2168 - val_acc: 0.9438 - val_mean_pred: 1.4314e-09
# Epoch 25/1000
#
# Epoch 00025: val_acc did not improve from 0.95938
# Learning_rate : 0.00040287783
# 6720/6720 - 1s - loss: 0.0117 - acc: 0.9960 - mean_pred: 5.7748e-10 - val_loss: 0.2509 - val_acc: 0.9375 - val_mean_pred: 1.3905e-09
# Epoch 26/1000
#
# Epoch 00026: val_acc did not improve from 0.95938
# Learning_rate : 0.00040287783
# 6720/6720 - 1s - loss: 0.0085 - acc: 0.9970 - mean_pred: 7.7035e-10 - val_loss: 0.2537 - val_acc: 0.9375 - val_mean_pred: 1.4104e-09
# Epoch 27/1000
#
# Epoch 00027: val_acc did not improve from 0.95938
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0003948202781612053.
# Learning_rate : 0.00039482026
# 6720/6720 - 1s - loss: 0.0067 - acc: 0.9979 - mean_pred: 8.8248e-10 - val_loss: 0.2800 - val_acc: 0.9406 - val_mean_pred: 1.9882e-09
# Epoch 28/1000
#
# Epoch 00028: val_acc did not improve from 0.95938
# Learning_rate : 0.00039482026
# 6720/6720 - 1s - loss: 0.0086 - acc: 0.9969 - mean_pred: 6.2973e-10 - val_loss: 0.2628 - val_acc: 0.9281 - val_mean_pred: 1.0539e-09
# Epoch 29/1000
#
# Epoch 00029: val_acc did not improve from 0.95938
# Learning_rate : 0.00039482026
# 6720/6720 - 1s - loss: 0.0091 - acc: 0.9969 - mean_pred: 8.8171e-10 - val_loss: 0.2569 - val_acc: 0.9406 - val_mean_pred: 9.3091e-10
# Epoch 30/1000
#
# Epoch 00030: val_acc did not improve from 0.95938
# Learning_rate : 0.00039482026
# 6720/6720 - 1s - loss: 0.0119 - acc: 0.9966 - mean_pred: 9.9805e-10 - val_loss: 0.2686 - val_acc: 0.9312 - val_mean_pred: 1.1203e-09
# Epoch 31/1000
#
# Epoch 00031: val_acc did not improve from 0.95938
# Learning_rate : 0.00039482026
# 6720/6720 - 1s - loss: 0.0074 - acc: 0.9969 - mean_pred: 7.0420e-10 - val_loss: 0.2293 - val_acc: 0.9375 - val_mean_pred: 3.3028e-10
# Epoch 32/1000
#
# Epoch 00032: val_acc did not improve from 0.95938
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0003869238594779745.
# Learning_rate : 0.00038692387
# 6720/6720 - 1s - loss: 0.0054 - acc: 0.9990 - mean_pred: 8.3438e-10 - val_loss: 0.2334 - val_acc: 0.9281 - val_mean_pred: -3.7750e-10
# Epoch 33/1000
#
# Epoch 00033: val_acc did not improve from 0.95938
# Learning_rate : 0.00038692387
# 6720/6720 - 1s - loss: 0.0113 - acc: 0.9960 - mean_pred: 7.8923e-10 - val_loss: 0.2605 - val_acc: 0.9469 - val_mean_pred: -2.8758e-10
# Epoch 34/1000
#
# Epoch 00034: val_acc did not improve from 0.95938
# Learning_rate : 0.00038692387
# 6720/6720 - 1s - loss: 0.0115 - acc: 0.9955 - mean_pred: 6.0236e-10 - val_loss: 0.2579 - val_acc: 0.9344 - val_mean_pred: 2.6637e-10
# Epoch 35/1000
#
# Epoch 00035: val_acc did not improve from 0.95938
# Learning_rate : 0.00038692387
# 6720/6720 - 1s - loss: 0.0072 - acc: 0.9976 - mean_pred: 7.1697e-10 - val_loss: 0.2426 - val_acc: 0.9281 - val_mean_pred: 1.7327e-09
# Epoch 36/1000
#
# Epoch 00036: val_acc did not improve from 0.95938
# Learning_rate : 0.00038692387
# 6720/6720 - 1s - loss: 0.0092 - acc: 0.9975 - mean_pred: 8.2632e-10 - val_loss: 0.2746 - val_acc: 0.9187 - val_mean_pred: 6.1857e-10
# Epoch 37/1000
#
# Epoch 00037: val_acc did not improve from 0.95938
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0003791853942675516.
# Learning_rate : 0.0003791854
# 6720/6720 - 1s - loss: 0.0077 - acc: 0.9975 - mean_pred: 1.1094e-09 - val_loss: 0.2486 - val_acc: 0.9344 - val_mean_pred: 1.2087e-09
# Epoch 38/1000
#
# Epoch 00038: val_acc did not improve from 0.95938
# Learning_rate : 0.0003791854
# 6720/6720 - 1s - loss: 0.0090 - acc: 0.9966 - mean_pred: 5.8569e-10 - val_loss: 0.3204 - val_acc: 0.9219 - val_mean_pred: -8.5804e-10
# Epoch 39/1000
#
# Epoch 00039: val_acc did not improve from 0.95938
# Learning_rate : 0.0003791854
# 6720/6720 - 1s - loss: 0.0071 - acc: 0.9975 - mean_pred: 8.3355e-10 - val_loss: 0.2116 - val_acc: 0.9594 - val_mean_pred: 1.5862e-09
# Epoch 40/1000
#
# Epoch 00040: val_acc did not improve from 0.95938
# Learning_rate : 0.0003791854
# 6720/6720 - 1s - loss: 0.0085 - acc: 0.9970 - mean_pred: 8.0801e-10 - val_loss: 0.2492 - val_acc: 0.9438 - val_mean_pred: 1.8127e-09
# Epoch 41/1000
#
# Epoch 00041: val_acc did not improve from 0.95938
# Learning_rate : 0.0003791854
# 6720/6720 - 1s - loss: 0.0051 - acc: 0.9981 - mean_pred: 1.1239e-09 - val_loss: 0.2731 - val_acc: 0.9438 - val_mean_pred: 2.4893e-09
# Epoch 42/1000
#
# Epoch 00042: val_acc did not improve from 0.95938
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.0003716016880935058.
# Learning_rate : 0.0003716017
# 6720/6720 - 1s - loss: 0.0054 - acc: 0.9982 - mean_pred: 8.3568e-10 - val_loss: 0.2453 - val_acc: 0.9500 - val_mean_pred: 1.0028e-09
# Epoch 43/1000
#
# Epoch 00043: val_acc did not improve from 0.95938
# Learning_rate : 0.0003716017
# 6720/6720 - 1s - loss: 0.0048 - acc: 0.9988 - mean_pred: 1.0890e-09 - val_loss: 0.2941 - val_acc: 0.9375 - val_mean_pred: 1.4388e-09
# Epoch 44/1000
#
# Epoch 00044: val_acc did not improve from 0.95938
# Learning_rate : 0.0003716017
# 6720/6720 - 1s - loss: 0.0039 - acc: 0.9984 - mean_pred: 1.1805e-09 - val_loss: 0.2697 - val_acc: 0.9344 - val_mean_pred: 3.8235e-10
# Epoch 45/1000
#
# Epoch 00045: val_acc did not improve from 0.95938
# Learning_rate : 0.0003716017
# 6720/6720 - 1s - loss: 0.0041 - acc: 0.9987 - mean_pred: 1.4650e-09 - val_loss: 0.2274 - val_acc: 0.9438 - val_mean_pred: 3.8647e-10
# Epoch 46/1000
#
# Epoch 00046: val_acc did not improve from 0.95938
# Learning_rate : 0.0003716017
# 6720/6720 - 1s - loss: 0.0067 - acc: 0.9976 - mean_pred: 1.0884e-09 - val_loss: 0.2328 - val_acc: 0.9406 - val_mean_pred: 1.4630e-09
# Epoch 47/1000
#
# Epoch 00047: val_acc did not improve from 0.95938
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0003641696606064215.
# Learning_rate : 0.00036416965
# 6720/6720 - 1s - loss: 0.0057 - acc: 0.9982 - mean_pred: 7.8445e-10 - val_loss: 0.2090 - val_acc: 0.9500 - val_mean_pred: -2.1227e-10
# Epoch 48/1000
#
# Epoch 00048: val_acc did not improve from 0.95938
# Learning_rate : 0.00036416965
# 6720/6720 - 1s - loss: 0.0097 - acc: 0.9970 - mean_pred: 1.2677e-09 - val_loss: 0.2484 - val_acc: 0.9469 - val_mean_pred: -3.6130e-10
# Epoch 49/1000
#
# Epoch 00049: val_acc did not improve from 0.95938
# Learning_rate : 0.00036416965
# 6720/6720 - 1s - loss: 0.0101 - acc: 0.9970 - mean_pred: 1.2905e-09 - val_loss: 0.2451 - val_acc: 0.9438 - val_mean_pred: 2.0562e-10
# Epoch 50/1000
#
# Epoch 00050: val_acc did not improve from 0.95938
# Learning_rate : 0.00036416965
# 6720/6720 - 1s - loss: 0.0091 - acc: 0.9972 - mean_pred: 8.3370e-10 - val_loss: 0.2296 - val_acc: 0.9500 - val_mean_pred: 1.1043e-09
# Epoch 51/1000
#
# Epoch 00051: val_acc did not improve from 0.95938
# Learning_rate : 0.00036416965
# 6720/6720 - 1s - loss: 0.0050 - acc: 0.9991 - mean_pred: 7.3774e-10 - val_loss: 0.2407 - val_acc: 0.9344 - val_mean_pred: 9.8042e-10
# Epoch 52/1000
#
# Epoch 00052: val_acc did not improve from 0.95938
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0003568862599786371.
# Learning_rate : 0.00035688627
# 6720/6720 - 1s - loss: 0.0034 - acc: 0.9991 - mean_pred: 9.2025e-10 - val_loss: 0.2457 - val_acc: 0.9500 - val_mean_pred: 1.7484e-09
# Epoch 53/1000
#
# Epoch 00053: val_acc did not improve from 0.95938
# Learning_rate : 0.00035688627
# 6720/6720 - 1s - loss: 0.0043 - acc: 0.9987 - mean_pred: 1.5177e-09 - val_loss: 0.2059 - val_acc: 0.9531 - val_mean_pred: 1.3991e-09
# Epoch 54/1000
#
# Epoch 00054: val_acc did not improve from 0.95938
# Learning_rate : 0.00035688627
# 6720/6720 - 1s - loss: 0.0061 - acc: 0.9988 - mean_pred: 8.0110e-10 - val_loss: 0.1987 - val_acc: 0.9594 - val_mean_pred: -5.7725e-10
# Epoch 55/1000
#
# Epoch 00055: val_acc did not improve from 0.95938
# Learning_rate : 0.00035688627
# 6720/6720 - 1s - loss: 0.0073 - acc: 0.9976 - mean_pred: 9.3739e-10 - val_loss: 0.2449 - val_acc: 0.9438 - val_mean_pred: -1.5302e-10
# Epoch 56/1000
#
# Epoch 00056: val_acc did not improve from 0.95938
# Learning_rate : 0.00035688627
# 6720/6720 - 1s - loss: 0.0067 - acc: 0.9979 - mean_pred: 8.8618e-10 - val_loss: 0.2034 - val_acc: 0.9563 - val_mean_pred: -8.9534e-10
# Epoch 57/1000
#
# Epoch 00057: val_acc did not improve from 0.95938
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0003497485484695062.
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0042 - acc: 0.9985 - mean_pred: 7.1291e-10 - val_loss: 0.2299 - val_acc: 0.9438 - val_mean_pred: 2.4941e-09
# Epoch 58/1000
#
# Epoch 00058: val_acc did not improve from 0.95938
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0031 - acc: 0.9988 - mean_pred: 1.2152e-09 - val_loss: 0.2169 - val_acc: 0.9500 - val_mean_pred: -5.5180e-10
# Epoch 59/1000
#
# Epoch 00059: val_acc did not improve from 0.95938
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0088 - acc: 0.9976 - mean_pred: 1.1603e-09 - val_loss: 0.2319 - val_acc: 0.9500 - val_mean_pred: -2.5621e-11
# Epoch 60/1000
#
# Epoch 00060: val_acc did not improve from 0.95938
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0054 - acc: 0.9975 - mean_pred: 1.3326e-09 - val_loss: 0.2238 - val_acc: 0.9469 - val_mean_pred: 1.0416e-09
# Epoch 61/1000
#
# Epoch 00061: val_acc did not improve from 0.95938
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0089 - acc: 0.9981 - mean_pred: 7.8045e-10 - val_loss: 0.2291 - val_acc: 0.9438 - val_mean_pred: 1.8650e-09
# Epoch 62/1000
#
# Epoch 00062: val_acc improved from 0.95938 to 0.96250, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0041 - acc: 0.9987 - mean_pred: 1.0358e-09 - val_loss: 0.2311 - val_acc: 0.9625 - val_mean_pred: 1.4280e-09
# Epoch 63/1000
#
# Epoch 00063: val_acc improved from 0.96250 to 0.97188, saving model to train_model/8.0_Transformer_Day4.h5
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0048 - acc: 0.9984 - mean_pred: 1.2922e-09 - val_loss: 0.2011 - val_acc: 0.9719 - val_mean_pred: -1.0388e-09
# Epoch 64/1000
#
# Epoch 00064: val_acc did not improve from 0.97188
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0190 - acc: 0.9940 - mean_pred: 8.6587e-10 - val_loss: 0.1886 - val_acc: 0.9375 - val_mean_pred: 1.3471e-09
# Epoch 65/1000
#
# Epoch 00065: val_acc did not improve from 0.97188
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0084 - acc: 0.9970 - mean_pred: 1.1146e-09 - val_loss: 0.1727 - val_acc: 0.9563 - val_mean_pred: 3.5105e-10
# Epoch 66/1000
#
# Epoch 00066: val_acc did not improve from 0.97188
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0069 - acc: 0.9976 - mean_pred: 1.0567e-09 - val_loss: 0.1890 - val_acc: 0.9500 - val_mean_pred: 1.5814e-09
# Epoch 67/1000
#
# Epoch 00067: val_acc did not improve from 0.97188
# Learning_rate : 0.00034974856
# 6720/6720 - 1s - loss: 0.0051 - acc: 0.9984 - mean_pred: 8.7928e-10 - val_loss: 0.2463 - val_acc: 0.9406 - val_mean_pred: 6.6070e-10
# Epoch 68/1000
#
# Epoch 00068: val_acc did not improve from 0.97188
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.0003427535883383825.
# Learning_rate : 0.0003427536
# 6720/6720 - 1s - loss: 0.0033 - acc: 0.9990 - mean_pred: 1.0253e-09 - val_loss: 0.1946 - val_acc: 0.9594 - val_mean_pred: 7.7972e-10
# Epoch 69/1000
#
# Epoch 00069: val_acc did not improve from 0.97188
# Learning_rate : 0.0003427536
# 6720/6720 - 1s - loss: 0.0047 - acc: 0.9990 - mean_pred: 1.1510e-09 - val_loss: 0.1964 - val_acc: 0.9656 - val_mean_pred: 1.1165e-09
# Epoch 70/1000
#
# Epoch 00070: val_acc did not improve from 0.97188
# Learning_rate : 0.0003427536
# 6720/6720 - 1s - loss: 0.0057 - acc: 0.9979 - mean_pred: 1.3170e-09 - val_loss: 0.1990 - val_acc: 0.9594 - val_mean_pred: 2.5425e-10
# Epoch 71/1000
#
# Epoch 00071: val_acc did not improve from 0.97188
# Learning_rate : 0.0003427536
# 6720/6720 - 1s - loss: 0.0042 - acc: 0.9984 - mean_pred: 1.1798e-09 - val_loss: 0.2054 - val_acc: 0.9563 - val_mean_pred: 3.1408e-10
# Epoch 72/1000
#
# Epoch 00072: val_acc did not improve from 0.97188
# Learning_rate : 0.0003427536
# 6720/6720 - 1s - loss: 0.0096 - acc: 0.9966 - mean_pred: 1.3073e-09 - val_loss: 0.2490 - val_acc: 0.9406 - val_mean_pred: -4.7053e-10
# Epoch 73/1000
#
# Epoch 00073: val_acc did not improve from 0.97188
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 0.00033589852740988134.
# Learning_rate : 0.00033589854
# 6720/6720 - 1s - loss: 0.0078 - acc: 0.9970 - mean_pred: 8.0449e-10 - val_loss: 0.2413 - val_acc: 0.9531 - val_mean_pred: -2.8234e-11
# Epoch 74/1000
#
# Epoch 00074: val_acc did not improve from 0.97188
# Learning_rate : 0.00033589854
# 6720/6720 - 1s - loss: 0.0074 - acc: 0.9975 - mean_pred: 1.2982e-09 - val_loss: 0.2157 - val_acc: 0.9531 - val_mean_pred: 2.3869e-09
# Epoch 75/1000
#
# Epoch 00075: val_acc did not improve from 0.97188
# Learning_rate : 0.00033589854
# 6720/6720 - 1s - loss: 0.0040 - acc: 0.9984 - mean_pred: 1.0310e-09 - val_loss: 0.2267 - val_acc: 0.9625 - val_mean_pred: 1.7242e-09
# Epoch 76/1000
#
# Epoch 00076: val_acc did not improve from 0.97188
# Learning_rate : 0.00033589854
# 6720/6720 - 1s - loss: 0.0035 - acc: 0.9987 - mean_pred: 1.2297e-09 - val_loss: 0.2258 - val_acc: 0.9563 - val_mean_pred: 1.6254e-09
# Epoch 77/1000
#
# Epoch 00077: val_acc did not improve from 0.97188
# Learning_rate : 0.00033589854
# 6720/6720 - 1s - loss: 0.0016 - acc: 0.9997 - mean_pred: 1.1290e-09 - val_loss: 0.2333 - val_acc: 0.9563 - val_mean_pred: -4.6119e-10
# Epoch 78/1000
#
# Epoch 00078: val_acc did not improve from 0.97188
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.00032918057055212555.
# Learning_rate : 0.00032918056
# 6720/6720 - 1s - loss: 0.0020 - acc: 0.9990 - mean_pred: 1.6776e-09 - val_loss: 0.2433 - val_acc: 0.9563 - val_mean_pred: 1.5463e-09
# Epoch 79/1000
#
# Epoch 00079: val_acc did not improve from 0.97188
# Learning_rate : 0.00032918056
# 6720/6720 - 1s - loss: 0.0022 - acc: 0.9994 - mean_pred: 9.1602e-10 - val_loss: 0.2435 - val_acc: 0.9656 - val_mean_pred: 1.1316e-09
# Epoch 80/1000
#
# Epoch 00080: val_acc did not improve from 0.97188
# Learning_rate : 0.00032918056
# 6720/6720 - 1s - loss: 0.0037 - acc: 0.9985 - mean_pred: 1.0165e-09 - val_loss: 0.2471 - val_acc: 0.9625 - val_mean_pred: 1.1006e-09
# Epoch 81/1000
#
# Epoch 00081: val_acc did not improve from 0.97188
# Learning_rate : 0.00032918056
# 6720/6720 - 1s - loss: 0.0044 - acc: 0.9985 - mean_pred: 9.1602e-10 - val_loss: 0.2797 - val_acc: 0.9500 - val_mean_pred: 5.9100e-10
# Epoch 82/1000
#
# Epoch 00082: val_acc did not improve from 0.97188
# Learning_rate : 0.00032918056
# 6720/6720 - 1s - loss: 0.0052 - acc: 0.9975 - mean_pred: 1.1488e-09 - val_loss: 0.2904 - val_acc: 0.9406 - val_mean_pred: 9.1932e-10
# Epoch 83/1000
#
# Epoch 00083: val_acc did not improve from 0.97188
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 0.000322596951154992.
# Learning_rate : 0.00032259696
# 6720/6720 - 1s - loss: 0.0073 - acc: 0.9970 - mean_pred: 7.7115e-10 - val_loss: 0.2635 - val_acc: 0.9469 - val_mean_pred: 1.0812e-10
# Epoch 84/1000
#
# Epoch 00084: val_acc did not improve from 0.97188
# Learning_rate : 0.00032259696
# 6720/6720 - 1s - loss: 0.0029 - acc: 0.9990 - mean_pred: 9.6902e-10 - val_loss: 0.3030 - val_acc: 0.9406 - val_mean_pred: 1.2834e-10
# Epoch 85/1000
#
# Epoch 00085: val_acc did not improve from 0.97188
# Learning_rate : 0.00032259696
# 6720/6720 - 1s - loss: 0.0031 - acc: 0.9987 - mean_pred: 1.2387e-09 - val_loss: 0.2381 - val_acc: 0.9531 - val_mean_pred: -8.8387e-11
# Epoch 86/1000
#
# Epoch 00086: val_acc did not improve from 0.97188
# Learning_rate : 0.00032259696
# 6720/6720 - 1s - loss: 0.0036 - acc: 0.9985 - mean_pred: 1.0418e-09 - val_loss: 0.2501 - val_acc: 0.9563 - val_mean_pred: -2.8578e-10
# Epoch 87/1000
#
# Epoch 00087: val_acc did not improve from 0.97188
# Learning_rate : 0.00032259696
# 6720/6720 - 1s - loss: 0.0023 - acc: 0.9991 - mean_pred: 1.1404e-09 - val_loss: 0.2641 - val_acc: 0.9594 - val_mean_pred: 8.5226e-10
# Epoch 88/1000
#
# Epoch 00088: val_acc did not improve from 0.97188
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.0003161450166953728.
# Learning_rate : 0.00031614501
# 6720/6720 - 1s - loss: 0.0014 - acc: 0.9997 - mean_pred: 1.3564e-09 - val_loss: 0.2907 - val_acc: 0.9531 - val_mean_pred: 1.6275e-09
# Epoch 89/1000
#
# Epoch 00089: val_acc did not improve from 0.97188
# Learning_rate : 0.00031614501
# 6720/6720 - 1s - loss: 0.0013 - acc: 0.9997 - mean_pred: 1.0251e-09 - val_loss: 0.2846 - val_acc: 0.9500 - val_mean_pred: 1.8415e-09
# Epoch 90/1000
#
# Epoch 00090: val_acc did not improve from 0.97188
# Learning_rate : 0.00031614501
# 6720/6720 - 1s - loss: 0.0018 - acc: 0.9994 - mean_pred: 9.3262e-10 - val_loss: 0.2809 - val_acc: 0.9531 - val_mean_pred: -2.3687e-10
# Epoch 91/1000
#
# Epoch 00091: val_acc did not improve from 0.97188
# Learning_rate : 0.00031614501
# 6720/6720 - 1s - loss: 0.0016 - acc: 0.9996 - mean_pred: 1.1825e-09 - val_loss: 0.2721 - val_acc: 0.9563 - val_mean_pred: 1.3535e-09
# Epoch 92/1000
#
# Epoch 00092: val_acc did not improve from 0.97188
# Learning_rate : 0.00031614501
# 6720/6720 - 1s - loss: 0.0034 - acc: 0.9981 - mean_pred: 1.1411e-09 - val_loss: 0.2761 - val_acc: 0.9500 - val_mean_pred: 2.4030e-10
# Epoch 93/1000
#
# Epoch 00093: val_acc did not improve from 0.97188
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.00030982211465016004.
# Learning_rate : 0.00030982212
# 6720/6720 - 1s - loss: 0.0043 - acc: 0.9985 - mean_pred: 1.3246e-09 - val_loss: 0.2782 - val_acc: 0.9469 - val_mean_pred: 1.2958e-09
# Epoch 94/1000
#
# Epoch 00094: val_acc did not improve from 0.97188
# Learning_rate : 0.00030982212
# 6720/6720 - 1s - loss: 0.0069 - acc: 0.9979 - mean_pred: 9.1729e-10 - val_loss: 0.2624 - val_acc: 0.9500 - val_mean_pred: -4.2549e-11
# Epoch 95/1000
#
# Epoch 00095: val_acc did not improve from 0.97188
# Learning_rate : 0.00030982212
# 6720/6720 - 1s - loss: 0.0093 - acc: 0.9969 - mean_pred: 1.2049e-09 - val_loss: 0.2528 - val_acc: 0.9500 - val_mean_pred: 3.1120e-10
# Epoch 96/1000
#
# Epoch 00096: val_acc did not improve from 0.97188
# Learning_rate : 0.00030982212
# 6720/6720 - 1s - loss: 0.0057 - acc: 0.9978 - mean_pred: 1.0012e-09 - val_loss: 0.2927 - val_acc: 0.9375 - val_mean_pred: 3.9019e-10
# Epoch 97/1000
#
# Epoch 00097: val_acc did not improve from 0.97188
# Learning_rate : 0.00030982212
# 6720/6720 - 1s - loss: 0.0087 - acc: 0.9963 - mean_pred: 1.0232e-09 - val_loss: 0.3270 - val_acc: 0.9250 - val_mean_pred: -5.9523e-10
# Epoch 98/1000
#
# Epoch 00098: val_acc did not improve from 0.97188
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.0003036256780615076.
# Learning_rate : 0.00030362568
# 6720/6720 - 1s - loss: 0.0071 - acc: 0.9976 - mean_pred: 1.0640e-09 - val_loss: 0.2879 - val_acc: 0.9375 - val_mean_pred: 4.3324e-10
# Epoch 99/1000
#
# Epoch 00099: val_acc did not improve from 0.97188
# Learning_rate : 0.00030362568
# 6720/6720 - 1s - loss: 0.0042 - acc: 0.9988 - mean_pred: 1.2124e-09 - val_loss: 0.2685 - val_acc: 0.9438 - val_mean_pred: 4.6747e-10
# Epoch 100/1000
#
# Epoch 00100: val_acc did not improve from 0.97188
# Learning_rate : 0.00030362568
# 6720/6720 - 1s - loss: 0.0059 - acc: 0.9978 - mean_pred: 1.2393e-09 - val_loss: 0.2453 - val_acc: 0.9500 - val_mean_pred: 9.8382e-10
# Epoch 101/1000
#
# Epoch 00101: val_acc did not improve from 0.97188
# Learning_rate : 0.00030362568
# 6720/6720 - 1s - loss: 0.0025 - acc: 0.9993 - mean_pred: 1.1599e-09 - val_loss: 0.2576 - val_acc: 0.9531 - val_mean_pred: 1.5495e-09
# Epoch 102/1000
#
# Epoch 00102: val_acc did not improve from 0.97188
# Learning_rate : 0.00030362568
# 6720/6720 - 1s - loss: 0.0031 - acc: 0.9990 - mean_pred: 8.8674e-10 - val_loss: 0.2347 - val_acc: 0.9688 - val_mean_pred: -4.9566e-10
# Epoch 103/1000
#
# Epoch 00103: val_acc did not improve from 0.97188
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 0.000297553168493323.
# Learning_rate : 0.00029755317
# 6720/6720 - 1s - loss: 0.0022 - acc: 0.9991 - mean_pred: 1.3383e-09 - val_loss: 0.2532 - val_acc: 0.9656 - val_mean_pred: 1.0943e-09
# Epoch 104/1000
#
# Epoch 00104: val_acc did not improve from 0.97188
# Learning_rate : 0.00029755317
# 6720/6720 - 1s - loss: 0.0026 - acc: 0.9987 - mean_pred: 1.3725e-09 - val_loss: 0.2909 - val_acc: 0.9594 - val_mean_pred: 8.2038e-10
# Epoch 105/1000
#
# Epoch 00105: val_acc did not improve from 0.97188
# Learning_rate : 0.00029755317
# 6720/6720 - 1s - loss: 0.0043 - acc: 0.9990 - mean_pred: 8.8115e-10 - val_loss: 0.3014 - val_acc: 0.9563 - val_mean_pred: -1.0165e-09
# Epoch 106/1000
#
# Epoch 00106: val_acc did not improve from 0.97188
# Learning_rate : 0.00029755317
# 6720/6720 - 1s - loss: 0.0031 - acc: 0.9988 - mean_pred: 1.1465e-09 - val_loss: 0.3470 - val_acc: 0.9469 - val_mean_pred: 4.1618e-10
# Epoch 107/1000
#
# Epoch 00107: val_acc did not improve from 0.97188
# Learning_rate : 0.00029755317
# 6720/6720 - 1s - loss: 0.0018 - acc: 0.9997 - mean_pred: 9.9328e-10 - val_loss: 0.3355 - val_acc: 0.9469 - val_mean_pred: -9.6906e-12
# Epoch 108/1000
#
# Epoch 00108: val_acc did not improve from 0.97188
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 0.0002916021045530215.
# Learning_rate : 0.0002916021
# 6720/6720 - 1s - loss: 0.0054 - acc: 0.9979 - mean_pred: 1.1691e-09 - val_loss: 0.3572 - val_acc: 0.9438 - val_mean_pred: 1.0773e-09
# Epoch 109/1000
#
# Epoch 00109: val_acc did not improve from 0.97188
# Learning_rate : 0.0002916021
# 6720/6720 - 1s - loss: 0.0032 - acc: 0.9988 - mean_pred: 1.0115e-09 - val_loss: 0.3182 - val_acc: 0.9563 - val_mean_pred: 1.0593e-09
# Epoch 110/1000
#
# Epoch 00110: val_acc did not improve from 0.97188
# Learning_rate : 0.0002916021
# 6720/6720 - 1s - loss: 0.0028 - acc: 0.9990 - mean_pred: 1.3245e-09 - val_loss: 0.3118 - val_acc: 0.9469 - val_mean_pred: 1.8352e-09
# Epoch 111/1000
#
# Epoch 00111: val_acc did not improve from 0.97188
# Learning_rate : 0.0002916021
# 6720/6720 - 1s - loss: 0.0033 - acc: 0.9990 - mean_pred: 9.9611e-10 - val_loss: 0.3671 - val_acc: 0.9531 - val_mean_pred: 2.2629e-10
# Epoch 112/1000
#
# Epoch 00112: val_acc did not improve from 0.97188
# Learning_rate : 0.0002916021
# 6720/6720 - 1s - loss: 0.0052 - acc: 0.9982 - mean_pred: 1.2114e-09 - val_loss: 0.3510 - val_acc: 0.9469 - val_mean_pred: 4.5030e-10
# Epoch 113/1000
#
# Epoch 00113: val_acc did not improve from 0.97188
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 0.000285770061891526.
# Learning_rate : 0.00028577007
# 6720/6720 - 1s - loss: 0.0029 - acc: 0.9988 - mean_pred: 1.1654e-09 - val_loss: 0.3752 - val_acc: 0.9375 - val_mean_pred: -9.9471e-11
# Epoch 114/1000
#
# Epoch 00114: val_acc did not improve from 0.97188
# Learning_rate : 0.00028577007
# 6720/6720 - 1s - loss: 0.0034 - acc: 0.9994 - mean_pred: 1.3683e-09 - val_loss: 0.3471 - val_acc: 0.9531 - val_mean_pred: 2.0902e-09
# Epoch 115/1000
#
# Epoch 00115: val_acc did not improve from 0.97188
# Learning_rate : 0.00028577007
# 6720/6720 - 1s - loss: 0.0026 - acc: 0.9988 - mean_pred: 1.1137e-09 - val_loss: 0.3882 - val_acc: 0.9531 - val_mean_pred: 1.1845e-10
# Epoch 116/1000
#
# Epoch 00116: val_acc did not improve from 0.97188
# Learning_rate : 0.00028577007
# 6720/6720 - 1s - loss: 0.0021 - acc: 0.9996 - mean_pred: 1.3829e-09 - val_loss: 0.3403 - val_acc: 0.9500 - val_mean_pred: 9.8602e-11
# Epoch 117/1000
#
# Epoch 00117: val_acc did not improve from 0.97188
# Learning_rate : 0.00028577007
# 6720/6720 - 1s - loss: 0.0017 - acc: 0.9993 - mean_pred: 1.2026e-09 - val_loss: 0.3788 - val_acc: 0.9344 - val_mean_pred: 1.9662e-10
# Epoch 118/1000
#
# Epoch 00118: val_acc did not improve from 0.97188
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 0.0002800546732032672.
# Learning_rate : 0.00028005466
# 6720/6720 - 1s - loss: 0.0031 - acc: 0.9994 - mean_pred: 1.2667e-09 - val_loss: 0.3295 - val_acc: 0.9438 - val_mean_pred: 1.3158e-09
# Epoch 119/1000
#
# Epoch 00119: val_acc did not improve from 0.97188
# Learning_rate : 0.00028005466
# 6720/6720 - 1s - loss: 0.0015 - acc: 0.9999 - mean_pred: 1.3305e-09 - val_loss: 0.3657 - val_acc: 0.9531 - val_mean_pred: -8.3295e-11
# Epoch 120/1000
#
# Epoch 00120: val_acc did not improve from 0.97188
# Learning_rate : 0.00028005466
# 6720/6720 - 1s - loss: 0.0028 - acc: 0.9991 - mean_pred: 1.4109e-09 - val_loss: 0.3446 - val_acc: 0.9375 - val_mean_pred: 1.1496e-09
# Epoch 121/1000
#
# Epoch 00121: val_acc did not improve from 0.97188
# Learning_rate : 0.00028005466
# 6720/6720 - 1s - loss: 0.0038 - acc: 0.9990 - mean_pred: 1.2024e-09 - val_loss: 0.3515 - val_acc: 0.9406 - val_mean_pred: 6.2104e-10
# Epoch 122/1000
#
# Epoch 00122: val_acc did not improve from 0.97188
# Learning_rate : 0.00028005466
# 6720/6720 - 1s - loss: 0.0020 - acc: 0.9996 - mean_pred: 1.3534e-09 - val_loss: 0.3313 - val_acc: 0.9469 - val_mean_pred: -3.5686e-12
# Epoch 123/1000
#
# Epoch 00123: val_acc did not improve from 0.97188
#
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 0.00027445357118267567.
# Learning_rate : 0.00027445357
# 6720/6720 - 1s - loss: 0.0021 - acc: 0.9993 - mean_pred: 1.0641e-09 - val_loss: 0.3191 - val_acc: 0.9469 - val_mean_pred: 1.4004e-09
# Epoch 124/1000
#
# Epoch 00124: val_acc did not improve from 0.97188
# Learning_rate : 0.00027445357
# 6720/6720 - 1s - loss: 0.0031 - acc: 0.9990 - mean_pred: 1.1111e-09 - val_loss: 0.2998 - val_acc: 0.9500 - val_mean_pred: 2.6926e-09
# Epoch 125/1000
#
# Epoch 00125: val_acc did not improve from 0.97188
# Learning_rate : 0.00027445357
# 6720/6720 - 1s - loss: 0.0030 - acc: 0.9987 - mean_pred: 1.2702e-09 - val_loss: 0.3092 - val_acc: 0.9531 - val_mean_pred: 6.3775e-10
# Epoch 126/1000
#
# Epoch 00126: val_acc did not improve from 0.97188
# Learning_rate : 0.00027445357
# 6720/6720 - 1s - loss: 0.0018 - acc: 0.9991 - mean_pred: 9.0854e-10 - val_loss: 0.2682 - val_acc: 0.9563 - val_mean_pred: 8.8503e-10
# Epoch 127/1000
#
# Epoch 00127: val_acc did not improve from 0.97188
# Learning_rate : 0.00027445357
# 6720/6720 - 1s - loss: 0.0018 - acc: 0.9993 - mean_pred: 1.2786e-09 - val_loss: 0.2687 - val_acc: 0.9500 - val_mean_pred: 1.0975e-09
# Epoch 128/1000
#
# Epoch 00128: val_acc did not improve from 0.97188
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 0.0002689645026111975.
# Learning_rate : 0.0002689645
# 6720/6720 - 1s - loss: 0.0045 - acc: 0.9982 - mean_pred: 1.2816e-09 - val_loss: 0.2113 - val_acc: 0.9594 - val_mean_pred: 4.3476e-10
# Epoch 129/1000
#
# Epoch 00129: val_acc did not improve from 0.97188
# Learning_rate : 0.0002689645
# 6720/6720 - 1s - loss: 0.0032 - acc: 0.9990 - mean_pred: 1.2280e-09 - val_loss: 0.2520 - val_acc: 0.9406 - val_mean_pred: 2.6559e-09
# Epoch 130/1000
#
# Epoch 00130: val_acc did not improve from 0.97188
# Learning_rate : 0.0002689645
# 6720/6720 - 1s - loss: 0.0023 - acc: 0.9991 - mean_pred: 1.0799e-09 - val_loss: 0.2323 - val_acc: 0.9656 - val_mean_pred: 1.4016e-09
# Epoch 131/1000
#
# Epoch 00131: val_acc did not improve from 0.97188
# Learning_rate : 0.0002689645
# 6720/6720 - 1s - loss: 0.0014 - acc: 0.9994 - mean_pred: 1.5236e-09 - val_loss: 0.2319 - val_acc: 0.9688 - val_mean_pred: 1.2261e-09
# Epoch 132/1000
#
# Epoch 00132: val_acc did not improve from 0.97188
# Learning_rate : 0.0002689645
# 6720/6720 - 1s - loss: 0.0030 - acc: 0.9988 - mean_pred: 1.2813e-09 - val_loss: 0.2406 - val_acc: 0.9625 - val_mean_pred: 7.1024e-10
# Epoch 133/1000
#
# Epoch 00133: val_acc did not improve from 0.97188
#
# Epoch 00133: ReduceLROnPlateau reducing learning rate to 0.0002635852142702788.
# Learning_rate : 0.0002635852
# 6720/6720 - 1s - loss: 0.0018 - acc: 0.9993 - mean_pred: 1.2300e-09 - val_loss: 0.2464 - val_acc: 0.9531 - val_mean_pred: 8.8007e-10
# Epoch 134/1000
#
# Epoch 00134: val_acc did not improve from 0.97188
# Learning_rate : 0.0002635852
# 6720/6720 - 1s - loss: 0.0033 - acc: 0.9984 - mean_pred: 9.0735e-10 - val_loss: 0.2409 - val_acc: 0.9594 - val_mean_pred: 9.9209e-10
# Epoch 135/1000
#
# Epoch 00135: val_acc did not improve from 0.97188
# Learning_rate : 0.0002635852
# 6720/6720 - 1s - loss: 0.0019 - acc: 0.9994 - mean_pred: 1.4147e-09 - val_loss: 0.2432 - val_acc: 0.9625 - val_mean_pred: 1.7397e-10
# Epoch 136/1000
#
# Epoch 00136: val_acc did not improve from 0.97188
# Learning_rate : 0.0002635852
# 6720/6720 - 1s - loss: 0.0025 - acc: 0.9993 - mean_pred: 1.3685e-09 - val_loss: 0.2775 - val_acc: 0.9531 - val_mean_pred: 1.2192e-09
# Epoch 137/1000
#
# Epoch 00137: val_acc did not improve from 0.97188
# Learning_rate : 0.0002635852
# 6720/6720 - 1s - loss: 0.0036 - acc: 0.9987 - mean_pred: 1.2013e-09 - val_loss: 0.2385 - val_acc: 0.9500 - val_mean_pred: 4.8000e-10
# Epoch 138/1000
#
# Epoch 00138: val_acc did not improve from 0.97188
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 0.0002583135099848732.
# Learning_rate : 0.00025831352
# 6720/6720 - 1s - loss: 0.0011 - acc: 0.9997 - mean_pred: 1.1887e-09 - val_loss: 0.2611 - val_acc: 0.9531 - val_mean_pred: 6.1472e-10
# Epoch 139/1000
#
# Epoch 00139: val_acc did not improve from 0.97188
# Learning_rate : 0.00025831352
# 6720/6720 - 1s - loss: 0.0026 - acc: 0.9996 - mean_pred: 1.0976e-09 - val_loss: 0.2642 - val_acc: 0.9531 - val_mean_pred: 7.4792e-11
# Epoch 140/1000
#
# Epoch 00140: val_acc did not improve from 0.97188
# Learning_rate : 0.00025831352
# 6720/6720 - 1s - loss: 0.0019 - acc: 0.9996 - mean_pred: 1.1378e-09 - val_loss: 0.2488 - val_acc: 0.9563 - val_mean_pred: 1.8639e-10
# Epoch 141/1000
#
# Epoch 00141: val_acc did not improve from 0.97188
# Learning_rate : 0.00025831352
# 6720/6720 - 1s - loss: 0.0014 - acc: 0.9996 - mean_pred: 1.2986e-09 - val_loss: 0.2680 - val_acc: 0.9531 - val_mean_pred: 1.8818e-09
# Epoch 142/1000
#
# Epoch 00142: val_acc did not improve from 0.97188
# Learning_rate : 0.00025831352
# 6720/6720 - 1s - loss: 0.0032 - acc: 0.9991 - mean_pred: 1.1205e-09 - val_loss: 0.3389 - val_acc: 0.9531 - val_mean_pred: 2.1237e-09
# Epoch 143/1000
#
# Epoch 00143: val_acc did not improve from 0.97188
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 0.00025314725062344225.
# Learning_rate : 0.00025314724
# 6720/6720 - 1s - loss: 0.0030 - acc: 0.9990 - mean_pred: 1.1249e-09 - val_loss: 0.3493 - val_acc: 0.9500 - val_mean_pred: 1.7752e-09
# Epoch 144/1000
#
# Epoch 00144: val_acc did not improve from 0.97188
# Learning_rate : 0.00025314724
# 6720/6720 - 1s - loss: 0.0044 - acc: 0.9984 - mean_pred: 1.0459e-09 - val_loss: 0.3207 - val_acc: 0.9375 - val_mean_pred: 1.9896e-09
# Epoch 145/1000
#
# Epoch 00145: val_acc did not improve from 0.97188
# Learning_rate : 0.00025314724
# 6720/6720 - 1s - loss: 0.0046 - acc: 0.9978 - mean_pred: 9.3082e-10 - val_loss: 0.4069 - val_acc: 0.9312 - val_mean_pred: 1.4641e-09
# Epoch 146/1000
#
# Epoch 00146: val_acc did not improve from 0.97188
# Learning_rate : 0.00025314724
# 6720/6720 - 1s - loss: 0.0063 - acc: 0.9988 - mean_pred: 1.0225e-09 - val_loss: 0.2998 - val_acc: 0.9375 - val_mean_pred: 1.2929e-09
# Epoch 147/1000
#
# Epoch 00147: val_acc did not improve from 0.97188
# Learning_rate : 0.00025314724
# 6720/6720 - 1s - loss: 0.0020 - acc: 0.9993 - mean_pred: 1.1844e-09 - val_loss: 0.3010 - val_acc: 0.9406 - val_mean_pred: 6.3542e-10
# Epoch 148/1000
#
# Epoch 00148: val_acc did not improve from 0.97188
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 0.0002480842970544472.
# Learning_rate : 0.0002480843
# 6720/6720 - 1s - loss: 0.0021 - acc: 0.9993 - mean_pred: 1.1070e-09 - val_loss: 0.3244 - val_acc: 0.9375 - val_mean_pred: 1.6662e-09
# Epoch 149/1000
#
# Epoch 00149: val_acc did not improve from 0.97188
# Learning_rate : 0.0002480843
# 6720/6720 - 1s - loss: 0.0022 - acc: 0.9994 - mean_pred: 1.2691e-09 - val_loss: 0.2987 - val_acc: 0.9500 - val_mean_pred: 2.7858e-10
# Epoch 150/1000
#
# Epoch 00150: val_acc did not improve from 0.97188
# Learning_rate : 0.0002480843
# 6720/6720 - 1s - loss: 7.8199e-04 - acc: 0.9999 - mean_pred: 1.5788e-09 - val_loss: 0.2725 - val_acc: 0.9438 - val_mean_pred: 1.9280e-10
# Epoch 151/1000
#
# Epoch 00151: val_acc did not improve from 0.97188
# Learning_rate : 0.0002480843
# 6720/6720 - 1s - loss: 0.0019 - acc: 0.9991 - mean_pred: 1.1983e-09 - val_loss: 0.2865 - val_acc: 0.9563 - val_mean_pred: 6.8489e-10
# Epoch 152/1000
#
# Epoch 00152: val_acc did not improve from 0.97188
# Learning_rate : 0.0002480843
# 6720/6720 - 1s - loss: 7.6158e-04 - acc: 0.9997 - mean_pred: 1.1868e-09 - val_loss: 0.2524 - val_acc: 0.9594 - val_mean_pred: 1.5075e-09
# Epoch 153/1000
#
# Epoch 00153: val_acc did not improve from 0.97188
#
# Epoch 00153: ReduceLROnPlateau reducing learning rate to 0.00024312262423336505.
# Learning_rate : 0.00024312263
# 6720/6720 - 1s - loss: 5.5583e-04 - acc: 1.0000 - mean_pred: 1.5256e-09 - val_loss: 0.2753 - val_acc: 0.9531 - val_mean_pred: -7.1701e-12
# Epoch 154/1000
#
# Epoch 00154: val_acc did not improve from 0.97188
# Learning_rate : 0.00024312263
# 6720/6720 - 1s - loss: 0.0013 - acc: 0.9996 - mean_pred: 1.3457e-09 - val_loss: 0.2646 - val_acc: 0.9438 - val_mean_pred: 5.0245e-10
# Epoch 155/1000
#
# Epoch 00155: val_acc did not improve from 0.97188
# Learning_rate : 0.00024312263
# 6720/6720 - 1s - loss: 0.0016 - acc: 0.9994 - mean_pred: 1.0013e-09 - val_loss: 0.2684 - val_acc: 0.9531 - val_mean_pred: 1.3299e-09
# Epoch 156/1000
#
# Epoch 00156: val_acc did not improve from 0.97188
# Learning_rate : 0.00024312263
# 6720/6720 - 1s - loss: 7.2311e-04 - acc: 0.9999 - mean_pred: 1.1124e-09 - val_loss: 0.2724 - val_acc: 0.9594 - val_mean_pred: 1.3616e-09
# Epoch 157/1000
#
# Epoch 00157: val_acc did not improve from 0.97188
# Learning_rate : 0.00024312263
# 6720/6720 - 1s - loss: 0.0016 - acc: 0.9994 - mean_pred: 1.1681e-09 - val_loss: 0.2701 - val_acc: 0.9563 - val_mean_pred: 1.7110e-09
# Epoch 158/1000
#
# Epoch 00158: val_acc did not improve from 0.97188
#
# Epoch 00158: ReduceLROnPlateau reducing learning rate to 0.00023826017859391866.
# Learning_rate : 0.00023826018
# 6720/6720 - 1s - loss: 0.0031 - acc: 0.9987 - mean_pred: 1.1996e-09 - val_loss: 0.2636 - val_acc: 0.9469 - val_mean_pred: 1.2809e-09
# Epoch 159/1000
#
# Epoch 00159: val_acc did not improve from 0.97188
# Learning_rate : 0.00023826018
# 6720/6720 - 1s - loss: 0.0048 - acc: 0.9979 - mean_pred: 1.2741e-09 - val_loss: 0.2895 - val_acc: 0.9500 - val_mean_pred: 1.0925e-09
# Epoch 160/1000
#
# Epoch 00160: val_acc did not improve from 0.97188
# Learning_rate : 0.00023826018
# 6720/6720 - 1s - loss: 0.0051 - acc: 0.9985 - mean_pred: 1.0272e-09 - val_loss: 0.2216 - val_acc: 0.9531 - val_mean_pred: 8.1301e-10
# Epoch 161/1000
#
# Epoch 00161: val_acc did not improve from 0.97188
# Learning_rate : 0.00023826018
# 6720/6720 - 1s - loss: 0.0061 - acc: 0.9975 - mean_pred: 1.1965e-09 - val_loss: 0.2520 - val_acc: 0.9531 - val_mean_pred: 3.2738e-09
# Epoch 162/1000
#
# Epoch 00162: val_acc did not improve from 0.97188
# Learning_rate : 0.00023826018
# 6720/6720 - 1s - loss: 0.0046 - acc: 0.9990 - mean_pred: 1.1814e-09 - val_loss: 0.2641 - val_acc: 0.9469 - val_mean_pred: 2.6004e-11
# Epoch 163/1000
#
# Epoch 00163: val_acc did not improve from 0.97188
#
# Epoch 00163: ReduceLROnPlateau reducing learning rate to 0.00023349497787421568.
# Learning_rate : 0.00023349498
# 6720/6720 - 1s - loss: 0.0025 - acc: 0.9987 - mean_pred: 9.3721e-10 - val_loss: 0.2679 - val_acc: 0.9469 - val_mean_pred: 7.7837e-10
# 320/320 [==============================] - ETA: 0s - loss: 0.1958 - acc: 0.9531 - mean_pred: 8.4171e-1 - 0s 66us/sample - loss: 0.2679 - acc: 0.9469 - mean_pred: 7.7837e-10
# accuracy:  0.946875 mean_pred:  7.7837187e-10
# [[127   6]
#  [  3 184]]
# DAY7 ROC_AUC_SCORE:  0.9694222186482249

# %%
if not os.path.exists('train_model/'+model_name+'.h5'):
    print('Trained model doesnt exist, changing evaluate_all_folds to False')
    evaluate_all_folds = False
if evaluate_all_folds:
    kfold, train_size, shuffle, split, fold_number,random_state = data_split()
    batch_size, time_steps, rm_window, hyperas_epochs, forecast_period, x_scaler = data_params()    
    df, y, ticker = feature_selection(forecast_period)
    
    def mean_pred(y_true, y_pred):
        return(K.mean(y_pred-y_true))
    
    
    model = load_model('train_model/'+model_name+'.h5', custom_objects={'mean_pred': mean_pred})
    print('loaded trained model')
    
    # add percent change
    df = percent_change(df)
    
    # apply preprocessing 
    x = x_scaler.fit_transform(df)
    del df
    y = y.values

    # apply time steps
  
    x, y = create_dataset(x, y, time_steps)
    
    
    #implementation of fold
    print('started Kfold')

    count = 0
    fd = KFold(n_splits=split, random_state=random_state, shuffle=shuffle)

    for train_index, test_index in fd.split(x):
        count +=1
        print('processing fold number ', count)

        _, x_test,_, y_test  = x[train_index], x[test_index], y[train_index], y[test_index]
        
        
        y_test = np_utils.to_categorical(y_test, 2, dtype='float32')
        

        # adjustment for batch_size
          
        test_start = x_test.shape[0]%batch_size
          
        x_test = x_test[test_start:]
        y_test = y_test[test_start:]
         
        
        loss,accuracy,mean_pred = model.evaluate([x_test], [y_test], batch_size=batch_size)
        
        print('Fold Number ', count, 'accuracy: ', accuracy,  'mean_pred: ', mean_pred)
       
        del x_test, y_test

# %%
def predict_selection(forecast_period):
    
    '''
    Function reads the dataset and prepares inputs and labels
    '''
    ticker = '^GSPC'  # ticker to classify
    stocks = ['A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES', 'AFL', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL', 'ALLE', 'ALXN', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APD', 'APH', 'APTV', 'ARE', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO', 'BA', 'BAC', 'BAX', 'BBY', 'BDX', 'BEN', 'BF-B', 'BIIB', 'BIO', 'BK', 'BKNG', 'BKR', 'BLK', 'BLL', 'BMY', 'BR', 'BRK-B', 'BSX', 'BWA', 'BXP', 'C', 'CAG', 'CAH', 'CARR', 'CAT', 'CB', 'CBOE', 'CBRE', 'CCI', 'CCL', 'CDNS', 'CDW', 'CE', 'CERN', 'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COO', 'COP', 'COST', 'CPB', 'CPRT', 'CRL', 'CRM', 'CSCO', 'CSX', 'CTAS', 'CTLT', 'CTSH', 'CTVA', 'CTXS', 'CVS', 'CVX', 'CZR', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIA', 'DIS', 'DISCA', 'DISCK', 'DISH', 'DLR', 'DLTR', 'DOV', 'DOW', 'DPZ', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DX-Y.NYB', 'DXC', 'DXCM', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR', 'ENPH', 'EOG', 'EQIX', 'EQR', 'ES', 'ESS', 'ETN', 'ETR', 'ETSY', 'EVRG', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST', 'FB', 'FBHS', 'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FLT', 'FMC', 'FOX', 'FOXA', 'FRC', 'FRT', 'FTNT', 'FTV', 'GD', 'GE', 'GILD', 'GIS', 'GL', 'GLW', 'GM', 'GNRC', 'GOOG', 'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HBAN', 'HBI', 'HCA', 'HD', 'HES', 'HIG', 'HII', 'HLT', 'HOLX', 'HON', 'HPE', 'HPQ', 'HRL', 'HSIC', 'HST', 'HSY', 'HUM', 'HWM', 'IBM', 'ICE', 'IDXX', 'IEX', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC', 'INTU', 'IP', 'IPG', 'IPGP', 'IQV', 'IR', 'IRM', 'ISRG', 'IT', 'ITW', 'IVZ', 'J', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'JPM', 'K', 'KEY', 'KEYS', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KR', 'KSU', 'L', 'LB', 'LDOS', 'LEG', 'LEN', 'LH', 'LHX', 'LIN', 'LKQ', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUMN', 'LUV', 'LVS', 'LW', 'LYB', 'LYV', 'MA', 'MAA', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC', 'MKTX', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOS', 'MPC', 'MPWR', 'MRK', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MXIM', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NI', 'NKE', 'NLOK', 'NLSN', 'NOC', 'NOV', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NVR', 'NWL', 'NWS', 'NWSA', 'NXPI', 'O', 'ODFL', 'OGN', 'OKE', 'OMC', 'ORCL', 'ORLY', 'OTIS', 'OXY', 'PAYC', 'PAYX', 'PBCT', 'PCAR', 'PEAK', 'PEG', 'PENN', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'POOL', 'PPG', 'PPL', 'PRGO', 'PRU', 'PSA', 'PSX', 'PTC', 'PVH', 'PWR', 'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'REGN', 'RF', 'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG', 'RTX', 'SBAC', 'SBUX', 'SCHW', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB', 'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SPY', 'SRE', 'STE', 'STT', 'STX', 'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG', 'TDY', 'TEL', 'TER', 'TFC', 'TFX', 'TGT', 'TJX', 'TMO', 'TMUS', 'TPR', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TT', 'TTWO', 'TWTR', 'TXN', 'TXT', 'TYL', 'UA', 'UAA', 'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URI', 'USB', 'V', 'VFC', 'VIAC', 'VLO', 'VMC', 'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VTRS', 'VZ', 'WAB', 'WAT', 'WBA', 'WDC', 'WEC', 'WELL', 'WFC', 'WHR', 'WLTW', 'WM', 'WMB', 'WMT', 'WRB', 'WRK', 'WST', 'WU', 'WY', 'WYNN', 'XEL', 'XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLNX', 'XLP', 'XLU', 'XLV', 'XLY', 'XOM', 'XRAY', 'XRT', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION', 'ZTS', '^GSPC', '^IXIC', '^NDX', '^SOX', '^TNX', '^VIX', '^VVIX', '^VXN', '^VXO', '^VXV']
    short_interest = ['Trading Volume']
    nytimes = ['neg', 'neu', 'pos']
    economic = ['Dividend', 'Earnings', 'CPI', 'Long Interest Rate', 'Real Price', 'Real Dividend', 'Real Earnings', 'Cyclically Adjusted PE Ratio', 'ECRI USLEADING LEVEL', 'ECRI USLEADING GROWTH', 'ECRI USLAGGING LEVEL', 'ECRI USLAGGING GROWTH', 'ECRI_USCOIN LEVEL', 'ECRI_USCOIN GROWTH', 'University of Michigan Consumer Survey, Index of Consumer Sentiment', 'Bullish', 'Neutral', 'Bearish', 'Bullish 8-Week Mov Avg', 'Bull-Bear Spread', 'Bullish Average', 'Bullish Average + St. Dev', 'Bullish Average - St. Dev', 'Stock Market Confidence Indices - United States One Year Index Data - Individual', 'Stock Market Confidence Indices - United States One Year Index Data - Institutional', 'Stock Market Confidence Indices - United States Buy on Dips Confidence Index Data - Individual', 'Stock Market Confidence Indices - United States Buy on Dips Confidence Index Data - Institutional', 'Stock Market Confidence Indices - United States Crash Confidence Index Data - Individual', 'Stock Market Confidence Indices - United States Crash Confidence Index Data - Institutional', 'Stock Market Confidence Indices - United States Valuation Index Data - Individual', 'Stock Market Confidence Indices - United States Valuation Index Data - Institutional', 'Zillow Home Value Index (Metro): Zillow Rental Index - All Homes - United States', 'Zillow Home Value Index (Metro): Turnover - All Homes - United States', 'Zillow Home Value Index (Metro): Price To Rent Ratio - All Homes - United States', 'Zillow Home Value Index (Metro): Median Listing Price - All Homes - United States', 'Zillow Home Value Index (Metro):  Home Sold As Foreclosure - Ratio - All Homes - United States', 'Historical Housing Market Data - Real Home Price Index', 'Cost Index', 'U.S. Population (Millions)', 'Long Rate', 'Historical Housing Market Data - Nominal Home Price Index', 'Historical Housing Market Data - Consumer Price Index (Quarterly)', '30-Year Conventional Mortgage Rate', 'House Price Index - US National', '15-Year Fix Rate', '15-Year Fix Rate Fees & Points', '5-Year Adjustable Rate', '5-Year Adjustable Rate Fees & Points', '1-Year Adjustable Rate', '1-Year Adjustable Rate Fees & Points', '30-Year Fixed Rate Mortgage Average in the United States', 'Federal Funds Rate', '90 day T Bill Rate', 'One Year Maturity Treasury Yield', 'Ten Year Maturity Treasury Yield', 'Freddie Mac Commitment Fixed Rate Mortgages', 'Freddie Mac Commitment ARMs', 'Prime Rate', 'Total Housing Starts', 'Single Family Housing Starts', 'Multi-Family Housing Starts', 'New Single-Family Sales', 'Existing Single-Family Home Sales', '1-Year CD: National Rate of Banks', '5-Year CD: National Rate of Banks', 'Interest Checking Accounts: National Rate of Banks', 'Money Market Accounts: National Rate of Banks', '1-Month AA Financial Commercial Paper Rate', '3-Month AA Financial Commercial Paper Rate', '1-Month AA Nonfinancial Commercial Paper Rate', '3-Month AA Nonfinancial Commercial Paper Rate', 'Effective Federal Funds Rate', '10-Year Treasury Inflation-Indexed Security, Constant Maturity', '20-Year Treasury Inflation-Indexed Security, Constant Maturity', '30-Year Treasury Inflation-Indexed Security, Constant Maturity', '5-Year Treasury Inflation-Indexed Security, Constant Maturity', '7-Year Treasury Inflation-Indexed Security, Constant Maturity', '10-Year Treasury Constant Maturity Rate', '2-Year Treasury Constant Maturity Rate', '20-Year Treasury Constant Maturity Rate', '3-Year Treasury Constant Maturity Rate', '30-Year Treasury Constant Maturity Rate', '5-Year Treasury Constant Maturity Rate', '7-Year Treasury Constant Maturity Rate', 'Bank Prime Loan Rate', '1-Year Treasury Bill: Secondary Market Rate', '3-Month Treasury Bill: Secondary Market Rate', '4-Week Treasury Bill: Secondary Market Rate', '6-Month Treasury Bill: Secondary Market Rate', 'Overnight London Interbank Offered Rate (LIBOR), based on U.S. Dollar', 'Finance Rate on Personal Loans at Commercial Banks, 24 Month Loan', 'Commercial Bank Interest Rate on Credit Card Plans, All Accounts', 'RR3_TBILL_PGDP_2', 'RR3_TBILL_PGDP_3', 'RR3_TBILL_PGDP_4', 'RR3_TBILL_PGDP_5', 'RR2_TBILL_CCPI_2', 'RR2_TBILL_CCPI_3', 'RR2_TBILL_CCPI_4', 'RR2_TBILL_CCPI_5', 'Gross domestic product', 'Personal consumption expenditures', ':Goods', '::Durable goods', '::Nondurable goods', ':Services', 'Gross private domestic investment', 'Net exports of goods and services', 'Government consumption expenditures and gross investment', '::Gross domestic income (GDI)', '::Gross national product', '::Gross national income', '::Disposable personal income', 'Personal income', ':Compensation of employees', '::Wages and salaries', ':Population (midperiod; thousands)', '::Disposable personal income; current dollars', 'Services', ':Household consumption expenditures (for services)', '::Housing and utilities', '::Health care', '::Transportation services', '::Recreation services', '::Food services and accommodations', '::Financial services and insurance', '::Other services', 'Corporate profits with inventory valuation and capital consumption adjustments', 'Consumer Price Index - USA', 'United States Gross National Savings, % of GDP', 'United States GDP at Constant Prices, % change', 'Nominal Potential Gross Domestic Product', 'Industrial Production: Durable Goods: Other durable goods', 'FRED: Projection of General government net lending/borrowing for United States', 'FRED: Real Potential Gross Domestic Product', 'FRED: Real Gross Domestic Product', 'FRED: Gross Domestic Product', 'FRBP: GDPplus GDP Growth', 'Inflation YOY - USA', 'Consumer Price Index for All Urban Consumers: All Items', 'PRCCPI1', 'PRCCPI2', 'PRCCPI3', 'PRCCPI4', 'PRCCPI5', 'PRCCPI6', 'PRCCPI7', 'PRCCPI8', 'PRCCPI9', 'PRCCPI10', 'PRCCPI11', 'PRCCPI12', 'PRCCPI13', 'PRCCPI14', 'PRCCPI15', 'PRCCPI16', 'PRCCPI17', 'PRCCPI18', 'PRCCPI19', 'PRCCPI20', 'Mean CPI1', 'Mean CPI2', 'Mean CPI3', 'Mean CPI4', 'Mean CPI5', 'Mean CPI6', 'Mean CPIA', 'Mean CPIB', 'Mean CPIC', 'Median CPI1', 'Median CPI2', 'Median CPI3', 'Median CPI4', 'Median CPI5', 'Median CPI6', 'Median CPIA', 'Median CPIB', 'Median CPIC', 'CORECPI1', 'CORECPI2', 'CORECPI3', 'CORECPI4', 'CORECPI5', 'CORECPI6', 'CORECPIA', 'CORECPIB', 'CORECPIC', 'Median CORECPI1', 'Median CORECPI2', 'Median CORECPI3', 'Median CORECPI4', 'Median CORECPI5', 'Median CORECPI6', 'Median CORECPIA', 'Median CORECPIB', 'Median CORECPIC', 'Employment; Openings; All industries; Rate (Percent) - National', 'Employment; Gross Job Losses; All industries; Rate (Percent) - National', 'Employment - All employees, quarterly averages, seasonally adjusted, thousands; Total nonfarm industry', 'Employment - All employees, thousands; Total private industry', 'Employment - All employees, thousands; Total nonfarm industry', 'Hires for Total nonfarm in Total US Region', 'Layoffs and discharges for Total nonfarm in Total US Region', 'Total separations for Total nonfarm in Total US Region', 'Hires percent for Total private in Total US Region', 'Job openings for Total private in Total US Region', 'Job openings percent for Total private in Total US Region', 'Total separations for Total private in Total US Region', 'Hires for Construction in Total US Region', 'Total separations for Construction in Total US Region', 'Hires for Manufacturing in Total US Region', 'Hires for Government in Total US Region', 'Total separations for Government in Total US Region', 'US Forecast Unemployment Rate, % of Total Labor Force', 'ISM Manufacturing Employment Index', 'ISM Non-Manufacturing Employment Index', 'FRED Forecast Natural Rate of Unemployment (Short-Term)', 'FRED Forecast Natural Rate of Unemployment (Long-Term)', 'ADP_Total private', 'ADP_Goods producing', 'Service providing', 'ADP_Goods Producing Industries_1-19', 'ADP_Goods Producing Industries_20-49', 'ADP_Goods Producing Industries_1-49', 'ADP_Goods Producing Industries_50-499', 'ADP_Goods Producing Industries_500+', 'ADP_Goods Producing Industries_500-999', 'ADP_Goods Producing Industries_1,000+', 'ADP_Construction', 'ADP_Natural resources & mining', 'Manufacturing', 'ADP_Prof.l/business services', 'ADP_Professional services', 'ADP_Total Non-Farm Private_1-19', 'ADP_Total Non-Farm Private_20-49', 'ADP_Total Non-Farm Private_1-49', 'ADP_Total Non-Farm Private_50-499', 'ADP_Total Non-Farm Private_500+', 'ADP_Total Non-Farm Private_500-999', '1000+', 'ADP_Private Service_1-19', 'ADP_Private Service_20-49', 'ADP_Private Service_1-49', 'ADP_Private Service_50-499', 'ADP_Private Service_500+', 'ADP_Private Service_500-999', 'ADP_Private Service_1,000+', 'Hand to Mouth-Manufacturing Buying Policy: Capital Expenditures', 'Average Days-Manufacturing Buying Policy: Capital Expenditures', 'Hand to Mouth-Manufacturing Buying Policy: MRO Supplies', 'Average Days-Manufacturing Buying Policy: MRO Supplies', 'Manufacturing Backlog of Orders Index', "Manufacturing Customers' Inventories Index", 'Manufacturing Supplier Deliveries Index', 'Manufacturing New Export Orders Index', 'Manufacturing Imports Index', 'Manufacturing Inventories Index', 'Manufacturing New Orders Index', 'Manufacturing Prices Index', 'Manufacturing Production Index', 'Non-Manufacturing Backlog of Orders Index', 'Non-Manufacturing Business Activity Index', 'Non-Manufacturing Supplier Deliveries Index', 'Non-Manufacturing New Export Orders Index', 'Non-Manufacturing Imports Index', 'Non-Manufacturing Inventories Index', 'Non-Manufacturing Inventory Sentiment Index', 'Non-Manufacturing New Orders Index', 'NMI Non-Manufacturing Index', 'Non-Manufacturing Prices Index', 'Gold Prices (Daily) - Currency USD', 'Milk, Nonfat dry, Chicago', 'Crude Oil Futures, Continuous Contract #1 (CL1) (Front Month)', 'UK Natural Gas Futures, Continuous Contract', 'Natural Gas (Henry Hub) Physical Futures, Continuous Contract #1 (NG1) (Front Month)', 'STEO price forecast, Monthly', 'US All Grades Conventional Gas Price', 'Copper Prices', 'Aluminum Prices', 'Silver Price: London Fixing', 'Seasonal Factors for the Empire State Manufacturing Survey - Future General Business Conditions - Percent Reporting Increase', 'Empire State Manufacturing Index - Forecasted Inventories - Diffusion Index (Seasonally Adjusted)', 'Seasonal Factors for the Empire State Manufacturing Survey - Current New Orders - Percent Reporting Decrease', 'Seasonal Factors for the Empire State Manufacturing Survey - Current New Orders - Percent Reporting Increase', 'Empire State Manufacturing Index - Forecasted Shipments - Diffusion Index (Seasonally Adjusted)', 'Empire State Manufacturing Index - Forecasted Unfilled Orders - Diffusion Index (Seasonally Adjusted)', 'Philly Fed Seasonally Adjusted Diffusion Indexes - Future New Orders', 'Philly Fed Seasonally Adjusted Diffusion Indexes - Future Shipments', 'Philly Fed Seasonally Adjusted Diffusion Indexes - Future Unfilled Orders', 'Future New Orders;Percent Reporting Increases for FRB - Philadelphia District']
    pattern = ['weekday_1', 'weekday_2', 'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 
    '''
    
    # add the list name with the '+' sign, stocks are prerequisite for calculating rolling mean
   
    selected_features = stocks+short_interest+nytimes+economic+pattern+correlations+technicals
    

    data_file = '../../models/process/sp500/data/'+ticker+'/'+ticker+'_7_days_0_return.csv'

    df=pd.read_csv(data_file, index_col = 0, parse_dates = True)['01-01-1993':] 
    
    
    #df=df[:-forecast_period] # if target return & Y target have NaN for forecast periods
        
    
        
    
    y = df[['^GSPC_{}d_target'.format(forecast_period)]]
   
    
    df = df[selected_features]
    remove_columns=([i for i in df.columns if df[i].isnull().any()]) # find Nan columns
    print('removed columns: ', remove_columns)
    df.drop(remove_columns, axis=1, inplace=True) # drop columns with NaN
    
    try: #to prevent error from not choosing the 'stocks' list for the dataframe(no ticker column)
        for a in range(2,rm_window+1):
            df[ticker+'rm_'+str(a)] = df[ticker].rolling(window=rm_window,center=False).mean()
        print('rolling mean columns added: ', rm_window)
        df = df[rm_window:] # slice to remove top rows with Nan generated due to rolling mean calc
        y = y[rm_window:] # slice to remove top rows with Nan generated due to rolling mean calc
    except:
        print('no stock ticker column selected. Therefore no rolling mean column added')
        pass
    
    

    return df, y, ticker

# %%
def create_predict_input(X, time_steps=1):
    Xs = []
    for i in range(len(X) - time_steps+1): 
        v = X[i:(i + time_steps)]
        Xs.append(v)
    return np.array(Xs)

# %%
def mean_pred(y_true, y_pred): # custom metrics
    return(K.mean(y_pred-y_true))

# %%
if evaluate_only:
    kfold, train_size, shuffle, split, fold_number,random_state = data_split()
    batch_size, time_steps, rm_window, hyperas_epochs, forecast_period, x_scaler = data_params()           
    x_train, x_test, y_train, y_test, batch_size,hyperas_epochs,x_predict, forecast_period, ticker= data()
    model = load_model('train_model/'+model_name+'.h5', custom_objects={'mean_pred': mean_pred})
    evaluate(model, x_test, x_predict, y_test,batch_size, forecast_period)
# Out:
# removed columns:  []
# rolling mean columns added:  64
# Prepared data with a train_test_split of  0.95
# [[127   6]
#  [  3 184]]
# DAY7 ROC_AUC_SCORE:  0.9694222186482249

# %%
if predict:
    batch_size, time_steps, rm_window, hyperas_epochs, forecast_period, x_scaler = data_params()
    df, y, ticker = predict_selection(forecast_period)
    kfold, train_size, shuffle, split, fold_number,random_state = data_split()
    df_forecast_range = df.index[-forecast_period*2:]

    # add percent change
    df = percent_change(df)

    # apply preprocessing 
    x = x_scaler.fit_transform(df)
    del df
    
    
    x = create_predict_input(x, time_steps)
    x_predict = x[-batch_size:]
    x_predict = x_predict.astype('float32')

   
    model = load_model('train_model/'+model_name+'.h5', custom_objects={'mean_pred': mean_pred})

    forecast_last_batch =  model.predict([x_predict], batch_size=batch_size)
    future_prediction = np.argmax(forecast_last_batch,axis=1)[-forecast_period*2:]
    future_probability = forecast_last_batch [-forecast_period*2:]

    nyse = mcal.get_calendar('NYSE') # NYSE Calendar
    date_range = nyse.schedule(df_forecast_range[0], '12-31-2021')[:3*forecast_period]
    forecast_date_range = date_range[forecast_period:]


    date_range = list(pd.to_datetime(date_range.market_close.dt.to_pydatetime()).strftime('%Y-%m-%d'))
    forecast_date_range = list(pd.to_datetime(forecast_date_range.market_close.dt.to_pydatetime()).strftime('%Y-%m-%d'))
    data = yf.download(ticker, start=date_range[0], end=date_range[-1])["Adj Close"]
    prior_values = data.values.tolist()[:forecast_period*2]
    data = pd.DataFrame(data)
    data['{}d change'.format(forecast_period)] =(data.shift(-forecast_period)-data)/data
    data.loc[data['{}d change'.format(forecast_period)] > 0.0, '{}d actual'.format(forecast_period)] = str(1)
    data.loc[data['{}d change'.format(forecast_period)] <= 0.0, '{}d actual'.format(forecast_period)] = str(0)
    data['{}d change'.format(forecast_period)] =data['{}d change'.format(forecast_period)].shift(forecast_period)
    data['{}d actual'.format(forecast_period)] =data['{}d actual'.format(forecast_period)].shift(forecast_period)
    data['Adj Close'] = data['Adj Close'].round(2)
    forecast = pd.DataFrame(index=forecast_date_range)
    forecast['prediction']=list(future_prediction)
    forecast['sell prob'] = list(pd.DataFrame(future_probability)[0].values)
    forecast['buy prob'] = list(pd.DataFrame(future_probability)[1].values)
    forecast['{}d prior'.format(forecast_period)] = list(pd.DataFrame(prior_values)[0].values)
    forecast['{}d prior'.format(forecast_period)] = forecast['{}d prior'.format(forecast_period)].round(2)
    data=forecast.join(data)
    data.loc[data['prediction'] == 1, 'price prediction'] = 'higher of ' + data['{}d prior'.format(forecast_period)].astype(str)
    data.loc[data['prediction'] == 0, 'price prediction'] = 'lower of ' + data['{}d prior'.format(forecast_period)].astype(str)      
    column_order = ['prediction','{}d actual'.format(forecast_period),'Adj Close', 'price prediction',  'sell prob', 'buy prob', '{}d change'.format(forecast_period)]
    data['Adj Close'] = data['Adj Close'].round(2)
    data['sell prob'] = (data['sell prob']*100).round(2).astype(str)+' %'
    data['buy prob'] = (data['buy prob']*100).round(2).astype(str)+' %'
    data['{}d change'.format(forecast_period)] = (data['{}d change'.format(forecast_period)]*100).round(2).astype(str)+' %'
    data=data[column_order]
    build_path('prediction')
    data.to_csv('prediction/'+model_name+'.csv')
    from IPython.display import display
    display(data)
# Out:
# removed columns:  []
# rolling mean columns added:  64
# [*********************100%***********************]  1 of 1 completed
# Directory  prediction  already exists
#             prediction 4d actual  Adj Close   price prediction sell prob  \
# 2021-06-08           1         1    4227.26  higher of 4208.12     0.0 %
# 2021-06-09           1         1    4219.55  higher of 4192.85     0.0 %
# 2021-06-10           1         1    4239.18  higher of 4229.89     0.0 %
# 2021-06-11           1         1    4247.44  higher of 4226.52     0.0 %
# 2021-06-14           1       NaN        NaN  higher of 4227.26     0.0 %
# 2021-06-15           1       NaN        NaN  higher of 4219.55     0.0 %
# 2021-06-16           1       NaN        NaN  higher of 4239.18     0.0 %
# 2021-06-17           1       NaN        NaN  higher of 4247.44     0.0 %
#
#            buy prob 4d change
# 2021-06-08  100.0 %    0.45 %
# 2021-06-09  100.0 %    0.64 %
# 2021-06-10  100.0 %    0.22 %
# 2021-06-11  100.0 %    0.49 %
# 2021-06-14  100.0 %     nan %
# 2021-06-15  100.0 %     nan %
# 2021-06-16  100.0 %     nan %
# 2021-06-17  100.0 %     nan %
